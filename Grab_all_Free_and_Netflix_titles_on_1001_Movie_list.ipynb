# %% [markdown]
# <a href="https://colab.research.google.com/github/JasmineElm/Notebooks/blob/master/Grab_all_Free_and_Netflix_titles_on_1001_Movie_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # identify movies on the 1001 movies list that are on
# + iPlayer
# + ITV Hub
# + BFi Player (free)
#
# The script will trawl through a large number of movies( bfi results in particular),  so will take some time to run.  Around 5 minutes for the script to complete ins not unreasonable.

# %% [markdown]
# # process
#
# Each service requires slightly different logic to get from the main (base) link to individual links.  the below table should give an overview of the logic required.
#
# In this context, full metadata simply means the service can return the movie title and year of release.  If a service cannot, we need to use OMDB or the like to ~~fill in~~ guess the blanks
#
# | service            | iPlayer | itvPlayer | bfiPlayer | Netflix |
# |--------------------|:-------:|:---------:|:---------:|:-------:|
# | main               | X       | X         | X         | X       |
# | paginated results  | X       |           | X         | X       |
# | individual results | X       | X         | X         |         |
# | Full Metadata      | X       |           | X         | X       |
# | requires OMDB      |         | X         |           | X       |

# %%
## grab our 1001 Movies List, download, and load into a dataframe 
url ='https://gist.githubusercontent.com/JasmineElm/ce8219c58bd416c0aec588a97e168221/raw/57717b4ae21f1721b2e1c22d2e8a74795e0e54d4/netflixTitles.csv'
r = requests.get(url)
filename = url.split('/')[-1]
 
with open(filename,'wb') as output_file:
    output_file.write(r.content)
    
ml=pd.read_csv(filename,index_col=[0])

# %% [markdown]
# # Expected Output
#
# The script should generate a markdown table in the following format:
#
# | Title              | Genre                             | Director       |   Year |   Runtime | Link                                                                     |
# |:-------------------|:----------------------------------|:---------------|-------:|----------:|:-------------------------------------------------------------------------|
# | A Trip to the Moon | Short, Adventure, Fantasy, Sci-Fi | Georges Méliès |   1902 |        13 | https://player.bfi.org.uk/free/film/watch-a-trip-to-the-moon-1902-online |
#
# An additional column flagging the service may be added to make the table easier to read.
#
# As a service could, quite legitimately, have no 1001 movie matches, the script should print a message where a service has been queried unsuccessfully.  e.g. ```bfi: no results```

# %%
# !pip install cfscrape
# Out:
# Requirement already satisfied: cfscrape in /usr/local/lib/python3.6/dist-packages (2.0.8)
# Requirement already satisfied: requests>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from cfscrape) (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.6.1->cfscrape) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.6.1->cfscrape) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.6.1->cfscrape) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.6.1->cfscrape) (2.8)

# %%
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep
from random import uniform  # for our sleep function
from tabulate import tabulate  # to export dataframe as markdown table
import requests, cfscrape, json
import urllib.request
import json


def scrapeSoup(url):
  scraper = cfscrape.create_scraper()
  webPage = scraper.get(url)
  soup = BeautifulSoup(webPage.text, "html5lib")
  return soup

    
def isYear(s):
    """ Returns a year if it looks 'legit'
        otherwise '0'
    """
    legit = False
    if s.isdigit():
        if 1880 <= int(s) <= 2030:
            legit = True
    return (0,s)[legit]

def progressBar(inList, currentStep, numeric=False):
    """ Prints a progress bar of sorts to make it easier to judge
        whether your loops are doing something. use in conjunction with 
        `enumerate` to get the index of the current step
    """
    ps = ['░', '▒', '▓', '█']
    if numeric:
        if currentStep == 0:
            print('iterations left: ', end='')
        print(len(inList)-currentStep, end=' ')
    else:
        if currentStep == 0:
            print('Progress: ', end='')
        stage = int(currentStep/len(inList)*len(ps))
        print(ps[stage], end='')

def isRuntime(s):
    """ checks if the first three passed characters
    "*" of a string look like a a runtime
    """
    legit = False
    if s[:3].isdigit():
        if 0 <= int(s[:3]) <= 999:
            legit = True
    return legit

def parseOMDB(query, full=False):
    """ queries OMDB returns data in a format similar to
        that used by the 1001 Movies List (full=True)
    """
    metadata = []
    ######## FIX THIS TO USE CFSCRAPE ##########
    with urllib.request.urlopen(query) as url:
        data = json.loads(url.read().decode())
        if full:
            metadata.append(data['Title'])
            metadata.append(data['Metascore'])
            metadata.append(data['Genre'])
            metadata.append(data['Director'])
            metadata.append(data['Language'])
            metadata.append(data['Country'])
            metadata.append(data['imdbRating'])
            metadata.append(data['Year'][:4])  # More appropriate to series...
            metadata.append(data['Plot'])
            metadata.append(data['Awards'])
            metadata.append(data['imdbID'])
            metadata.append(data['Runtime'][:-4])  # remove ' mins' at source
        else:
            metadata.append(data['Title'])
            metadata.append(data['Year'])
    return metadata

def cleanseTitle(s):
    """ removes bad case and spaces from search
        terms sent to OMDBapi
    """

    s = s.casefold()
    return s.replace(' ', '+')

def buildOMDBQuery(title, year=None, movie=True, apikey=None):
    """ simple function to build a query string for OMDB
        VERY beta: no logic around handling failed queries
    """
    omdbURL = 'https://www.omdbapi.com/?apikey='
    if apikey==None:
      print('API key required! get one from https://www.omdbapi.com/')
    title = '&t='+cleanseTitle(title)
    # 'and' can make the term too specific ('starsky and hutch' will not return the movie, 'starsky hutch' will)
    query = omdbURL+apikey+title
    if year != None:
        query = query+'&y='+year
    if movie == True:
        query = query+'&type=movie'
    return query

def iPlayerLinkList(urlList):
    """ 
    """
    soup=scrapeSoup(urlList[1])
    pageList = []
#     pl = [urList]
    pageList.append(urlList) 
    pl = []
    for link in soup.find('div', {'class': 'list__pagination'}).find_all('a'):
        if urlList[1]+link.get('href') != pageList[-1][1]:
            pl.append(urlList[0])
            pl.append(urlList[1]+link.get('href'))
            pageList.append(pl)
            pl = []
    return pageList

def bfiLinkList(urlList):
    """
    """
    pageList = []
    soup=scrapeSoup(urlList[1])
    base = 'https://player.bfi.org.uk'
    pl = []
    for collection in soup.findAll('div', {'class': 'collection-card'}):
        pl.append(urlList[0])
        pl.append(base+collection.find('a').get('href'))
        pageList.append(pl)
        pl = []
    return pageList


def netflixLinkList(urlList):
  """
  """
  pageList=[]
  page=[]
  baseLink="https://uk.newonnetflix.info/catalogue/a2z/all/"
  soup=scrapeSoup(urlList[1])
  for link in soup.find("span",{"class":"datemenu"}):
    if "".join(link).lower()!=" " and "".join(link).lower()!="\n":
      page=[]
      page.append(urlList[0])
      page.append(baseLink+"".join(link).lower())
      pageList.append(page)
  return pageList

def linkListBuilder(baseList):
    """
    """
    pageLinkList = []
    for item in baseList:
        if item[0] == 'itv':
            pageLinkList.append(item)
        elif item[0] == 'iplayer':
            for link in iPlayerLinkList(item):
                pageLinkList.append(link)
        elif item[0] == 'bfi':
            for link in bfiLinkList(item):
                pageLinkList.append(link)
        elif item[0] == 'netflix':
            for link in netflixLinkList(item):
                pageLinkList.append(link)
    return pageLinkList

def itvMoviePage(linkList):
    """ grab individual movie links from a
        page of itv listings
    """
    moviePage = []
    soup=scrapeSoup(linkList[1])
    # like iPlayer, the metadata exists only on the individual pages.
    movieList = []
    for category in soup.findAll('div', {'class', 'categories'}):
        for link in category.findAll('a', {'class': 'complex-link'}):
            movieList = []
            movieList.append(linkList[0])
            movieList.append(link.get('href'))
            moviePage.append(movieList)
    return moviePage

def iPlayerMoviePage(linkList):
    """ grab individual movie links from a
        page of iPlayer listings
    """
    movieDetails = []
    baseLink = 'https://www.bbc.co.uk'
    soup=scrapeSoup(linkList[1])
    for tile in soup.findAll('div', {'class': 'content-item'}):
        movieList = []
        movieList.append(linkList[0])
        movieList.append(baseLink+tile.find('a').get('href'))
        movieDetails.append(movieList)
    return movieDetails

def getMoviePages(linkList):
    """ iPlayer and itvHub keep metadata on
        individual movie pages.  this function
        captures those pages.  
        BFI and Netflix entries pass through
    """
    moviePage = []
    for itx, item in enumerate(linkList):
        progressBar(linkList, itx)
        if item[0] == 'itv':
            for link in itvMoviePage(item):
                moviePage.append(link)
        elif item[0] == 'iplayer':
            for link in iPlayerMoviePage(item):
                moviePage.append(link)
        elif item[0] == 'bfi':
            moviePage.append(item)
        elif item[0] == 'netflix':
            moviePage.append(item)
    return moviePage

def itvMovieData(moviePage, apikey=None):
    """
    """
    outerList = []
    movieLink=moviePage[1]
    outerList.append(movieLink)
    soup=scrapeSoup(movieLink)
    title = cleanseTitle(soup.find('h1').text)
    query = buildOMDBQuery(title, apikey=apikey)
    queryResults = parseOMDB(query)
    for result in queryResults:
        outerList.append(result)
    outerList.append(
        soup.find('li', {'class': 'episode-info__meta-item--availability'}).text)
    outerList.append(moviePage[0])
    return outerList

def iPlayerMovieData(moviePage):
    movieLink=moviePage[1]
    soup=scrapeSoup(movieLink)
    innerList = [moviePage[1]]
    movie = soup.find('div', {'class': 'play-cta__title-container'}).text
    innerList.append(
        soup.find('div', {'class': 'play-cta__title-container'}).text)
    meta = soup.find('div', {'class': 'gel-layout'}).findAll('li')
    for itx, metadata in enumerate(meta):
        if itx != 0:
            if itx == 1:
                innerList.append(metadata.find(
                    'span', {'class': 'episode-metadata__text'}).text[-4:])
            else:
                innerList.append(metadata.find(
                    'span', {'class': 'episode-metadata__text'}).text)
    innerList.append(moviePage[0])
    return innerList

def bfiMovieData(moviePage):
    base = 'https://player.bfi.org.uk'
    soup=scrapeSoup(moviePage[1])
    for card in soup.findAll('div', {'class': 'card--free'}):
        movieInfo = []
        movieInfo.append(base+card.find('a').get('href'))  # direct link
        movieInfo.append(card.find('h3').find('span').text)  # title
        if len(card.find('p', {'class': 'card__info'}).select("span:nth-of-type(2)")[0].text) == 4:
            movieInfo.append(card.find('p', {'class': 'card__info'}).select(
                "span:nth-of-type(2)")[0].text)
        else:
            # hacky way to ensure only years are parsed - needs fixing
            movieInfo.append('0')
        movieInfo.append('')
        movieInfo.append(moviePage[0])
        return movieInfo

def netflixMovieData(moviePage):
  movieData=[]
  empty=''
  soup=scrapeSoup(moviePage[1])
  for movieDetail in soup.find_all("a",{"class":"infopop"}):
    movieList=[]
    if movieDetail.find("img") == None:
      title = movieDetail.text[:-6].strip()
      year = isYear(movieDetail.text[-5:].strip(")").strip())
      movieList.append(empty)
      movieList.append(title)
      movieList.append(year)
      movieList.append(empty)
      movieList.append(moviePage[0])
    if len(movieList)==5:
      movieData.append(movieList)
  return movieData

def randSleep(minSleep=0.2, maxSleep=2.5):
    """ let's not spam servers.  
    """
    sleep(uniform(minSleep, maxSleep))

def getmovieData(moviePageList, apikey):
    """ for each page in list, grab the metadata
        if the page is itv, we also need to make a 
        call to omdb to guess the year.
    """
    movieDataList = []
    for itx, moviePage in enumerate(moviePageList):
        progressBar(moviePageList, itx)
        if moviePage[0] == 'itv':
            randSleep()
            movieDataList.append(itvMovieData(moviePage, apikey=apikey))
        elif moviePage[0] == 'iplayer':
            randSleep()
            movieDataList.append(iPlayerMovieData(moviePage))
        elif moviePage[0] == 'bfi':
            randSleep()
            movieDataList.append(bfiMovieData(moviePage))
        elif moviePage[0] == 'netflix':
            randSleep()
            for movie in netflixMovieData(moviePage):
              movieDataList.append(movie)
    return movieDataList

# %%
urlList=[['iplayer','https://www.bbc.co.uk/iplayer/categories/films/a-z']
        ,['itv',    'https://www.itv.com/hub/categories/films']
        ,['bfi',    'https://player.bfi.org.uk/free/collections']
        ,['netflix','https://uk.newonnetflix.info/catalogue/a2z/all']]

# %%
omdbAPI='' #########CHANGE ME#########
pll=linkListBuilder(urlList)
mp=getMoviePages(pll)
print('Getting movie data . . .')
metaDataList=getmovieData(mp, omdbAPI)
# Out:
# Progress: ░░░░░░░░░░░░░░░░░░░░░░░░░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓██████████████████████████Getting movie data . . .
# Progress: ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓██████████████████████████████████████

# %%
metaDataList
# Out:
# [['https://www.bbc.co.uk/iplayer/episode/p04b183c/adam-curtis-hypernormalisation',
#   'Adam Curtis',
#   '2016',
#   'Available for over a year',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/p07ctvvn/a-high-school-rape-goes-viral-roll-red-roll',
#   'A High School Rape Goes Viral: Roll Red Roll',
#   '2019',
#   'Available for 4 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b065jk5m/a-most-violent-year',
#   'A Most Violent Year',
#   '2014',
#   'Expires tonight 1:35am',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0078cwc/a-simple-plan',
#   'A Simple Plan',
#   '1998',
#   'Available for 3 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b01dtlxl/the-awakening',
#   'The Awakening',
#   '2011',
#   'Available for 17 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b06vq3yn/the-big-short',
#   'The Big Short',
#   '2015',
#   'Available until Tue 12:55am',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b010y7my/the-boy-in-the-striped-pyjamas',
#   'The Boy in the Striped Pyjamas',
#   '2008',
#   'Available for 9 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b06vyf02/brooklyn',
#   'Brooklyn',
#   '2015',
#   'Available for 23 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/m0001qyv/bros-after-the-screaming-stops',
#   'Bros: After the Screaming Stops',
#   '2018',
#   'Available until Mon 1am',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/p01c8jm8/burton-and-taylor',
#   'Burton and Taylor',
#   '2013',
#   'Available for 8 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0078ns6/cat-people',
#   'Cat People',
#   '1942',
#   'Available for over a year',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b060l93c/clouds-of-sils-maria',
#   'Clouds of Sils Maria',
#   '2014',
#   'Available for 24 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0078ygf/the-curse-of-the-cat-people',
#   'The Curse of the Cat People',
#   '1944',
#   'Available for over a year',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/p06zxzgk/diagnosis',
#   'Diagnosis',
#   '2019',
#   'Available for 5 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/m0007p9z/dirt-road-to-lafayette',
#   'Dirt Road to Lafayette',
#   '2016',
#   'Available for 24 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b01gxjs6/the-double',
#   'The Double',
#   '2011',
#   'Available until Sun 1:50am',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/p07dh199/the-edge-of-seventeen',
#   'The Edge of Seventeen',
#   '2019',
#   'Available for 4 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0bwdss2/happy-new-year-colin-burstead',
#   'Happy New Year, Colin Burstead',
#   '2018',
#   'Available for over a year',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b08kbrdk/home-from-home-chronicle-of-a-vision-part-2',
#   'Home from Home: Chronicle of a Vision',
#   '2013',
#   'Available for 17 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/m000777b/ibiza-the-silent-movie',
#   'Ibiza: The Silent Movie',
#   '2019',
#   'Available for 16 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0078t0v/i-walked-with-a-zombie',
#   'I Walked With a Zombie',
#   '1943',
#   'Available for over a year',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b007q86z/the-jackal',
#   'The Jackal',
#   '2019',
#   'Available for 2 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/p07ctstz/kate-nash-underestimate-the-girl',
#   'Kate Nash: Underestimate the Girl',
#   '2019',
#   'Available for 4 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0074fln/lara-croft-tomb-raider',
#   'Lara Croft: Tomb Raider',
#   '2001',
#   'Available for 3 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b007ck00/lara-croft-tomb-raider-the-cradle-of-life',
#   'Lara Croft Tomb Raider: The Cradle of Life',
#   '2003',
#   'Available for 3 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b007cjz1/man-on-the-moon',
#   'Man on the Moon',
#   '1999',
#   'Available for 3 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b06pdxyf/man-up',
#   'Man Up',
#   '2015',
#   'Available until Mon 1:30am',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/m000773f/midnight-special',
#   'Midnight Special',
#   '2016',
#   'Available for 10 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/p07cttsd/minding-the-gap-an-american-skateboarding-story',
#   'Minding the Gap: An American Skateboarding Story',
#   '2019',
#   'Available for 4 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/m0007944/next-big-thing-series-1-asset-management',
#   'Next Big Thing',
#   '2019',
#   'Available for 11 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0078pw1/night-of-the-living-dead',
#   'Night of the Living Dead',
#   '1968',
#   'Available for over a year',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b038z5hf/now-is-good',
#   'Now Is Good',
#   '2012',
#   'Available for 10 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0184xhh/the-other-man',
#   'The Other Man',
#   '2008',
#   'Available until Tue 1:15am',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b03ttndm/philomena',
#   'Philomena',
#   '2013',
#   'Available for 9 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b00749zc/primary-colors',
#   'Primary Colors',
#   '1998',
#   'Available for 3 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b01qbz9m/queen-of-versailles',
#   'Queen of Versailles',
#   '2013',
#   'Available for 4 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0074t6v/the-red-shoes',
#   'The Red Shoes',
#   '1948',
#   'Available for 16 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0074924/the-relic',
#   'The Relic',
#   '1997',
#   'Available for 3 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b08xdlts/rock-n-roll-guns-for-hire-the-story-of-the-sideman',
#   "Rock 'n' Roll Guns for Hire: The Story of the Sideman",
#   '2017',
#   'Available for 23 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b05zxj5s/shaun-the-sheep-the-movie',
#   'Shaun the Sheep the Movie',
#   '2015',
#   'Available for 9 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/p04sh6zg/simon-amstell-carnage',
#   'Simon Amstell: Carnage',
#   '2017',
#   'Available for over a year',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b06vt9qf/spotlight',
#   'Spotlight',
#   '2015',
#   'Available until Wed 12:45am',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b064jdqt/stations-of-the-cross',
#   'Stations of the Cross',
#   '2018',
#   'Available for 24 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/m0005prp/storyville-the-raft',
#   'Storyville',
#   '2019',
#   'Available for 3 months',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b01pzqj3/wallace-and-gromit-a-grand-day-out',
#   'Wallace and Gromit: A Grand Day Out',
#   '1992',
#   'Available for 17 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b00g8hbw/wallace-and-gromit-a-matter-of-loaf-and-death',
#   'Wallace and Gromit: A Matter of Loaf and Death',
#   '2008',
#   'Available until Sun 7:30pm',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b08nfjwt/wallace-and-gromit-the-wrong-trousers',
#   'Wallace and Gromit: The Wrong Trousers',
#   '1993',
#   'Available for 10 days',
#   'iplayer'],
#  ['https://www.bbc.co.uk/iplayer/episode/b0078nh3/wonder-boys',
#   'Wonder Boys',
#   '2000',
#   'Available for 3 months',
#   'iplayer'],
#  ['https://www.itv.com/hub/carry-on-behind/CFD0107',
#   'Carry on Behind',
#   '1975',
#   '16 days left',
#   'itv'],
#  ['https://www.itv.com/hub/carry-on-loving/CFD0116',
#   'Carry on Loving',
#   '1970',
#   '9 days left',
#   'itv'],
#  ['https://www.itv.com/hub/carry-on-follow-that-camel/CFD0121',
#   'Carry On... Follow That Camel',
#   '1967',
#   '23 days left',
#   'itv'],
#  ['https://player.bfi.org.uk/free/film/watch-the-body-beautiful-1990-online',
#   'The Body Beautiful',
#   '1990',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-colour-on-the-thames-1935-online',
#   'Colour on the Thames',
#   '0',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-prince-ranjitsinhji-practising-batting-at-the-nets-1897-online',
#   'Prince Ranjitsinhji Practising Batting at the Nets',
#   '1897',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-heinz-baked-beans-common-market-1972-online',
#   'Heinz Baked Beans : Common Market',
#   '1972',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-solar-eclipse-1900-online',
#   'Solar Eclipse',
#   '1900',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-whats-a-girl-like-you-1969-online',
#   "What's a Girl Like You ...",
#   '1969',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-george-best-at-21-1968-online',
#   'George Best at 21',
#   '1968',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-madness-of-the-dance-2006-online',
#   'The Madness of the Dance',
#   '2006',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-boy-and-bicycle-1965-online',
#   'Boy and Bicycle',
#   '1965',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-toniwithani-2019-online',
#   'toni_with_an_i',
#   '2019',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-tram-ride-through-sunderland-1904-1904-online',
#   'Tram Ride through Sunderland (1904)',
#   '1904',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-end-2011-online',
#   'The End',
#   '2011',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-body-beautiful-1990-online',
#   'The Body Beautiful',
#   '1990',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-spelga-dam-1960-online',
#   'Spelga Dam',
#   '1960',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-perfect-woman-1949-online',
#   'The Perfect Woman',
#   '1949',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-miss-davisons-funeral-1913-online',
#   "Miss Davison's Funeral",
#   '1913',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-outside-the-box-2018-online',
#   'Outside the Box',
#   '2018',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-dentist-1993-online',
#   'The Dentist',
#   '0',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-nelson-the-story-of-englands-immortal-naval-hero-1918-online',
#   "Nelson; The Story of England's Immortal Naval Hero",
#   '1918',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-max-beeza-and-the-city-in-the-sky-1977-online',
#   'Max Beeza and the City in the Sky',
#   '1977',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-some-of-my-best-friends-1969-online',
#   'Some of My Best Friends',
#   '1969',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-green-cross-code-hes-great-1976-online',
#   "Green Cross Code - He's Great",
#   '1976',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-hull-fair-1902-1902-online',
#   'Hull Fair (1902)',
#   '1902',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-panorama-of-calcutta-india-from-the-river-ganges-1899-online',
#   'Panorama of Calcutta, India, From the River Ganges.',
#   '1899',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-no-mischief-here-can-satan-find-for-idle-hands-to-do-1917-online',
#   'No Mischief Here Can Satan Find for Idle Hands to Do',
#   '0',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-shower-baths-in-the-trenches-1916-online',
#   'Shower Baths in the Trenches',
#   '1916',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-patrol-in-the-desert-1915-online',
#   'Patrol in the Desert',
#   '1915',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-lt-pimple-and-the-stolen-submarine-1914-online',
#   'Lt Pimple and the Stolen Submarine',
#   '1914',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-good-strong-coffee-1968-online',
#   'Good Strong Coffee',
#   '1968',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-schools-for-moslems-1980-online',
#   'Schools for Moslems',
#   '1980',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-victory-parade-1946-online',
#   'Victory Parade',
#   '1946',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-mistletoe-bough-1904-online',
#   'The Mistletoe Bough',
#   '1904',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-discomania-1979-online',
#   'Discomania',
#   '1979',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-toys-will-be-toys-1988-online',
#   'Toys Will Be Toys',
#   '1988',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-a-woman-undressing-1896-online',
#   'A Woman Undressing',
#   '1896',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-wedding-of-princess-elizabeth-and-philip-mountbatten-1947-online',
#   'Wedding of Princess Elizabeth and Philip Mountbatten',
#   '0',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-mining-review-25th-year-no-9-1972-online',
#   'Mining Review 25th Year No. 9',
#   '0',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-ibberson-family-and-ve-day-1945-online',
#   'Ibberson Family and VE Day',
#   '1945',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-high-treason-sound-version-1929-online',
#   'High Treason (sound version)',
#   '1929',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-inside-nazi-germany-1938-online',
#   'Inside Nazi Germany',
#   '1938',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-focii-1975-online',
#   'Focii',
#   '1975',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-strings-2012-online',
#   'Strings',
#   '2012',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-red-miss-2017-online',
#   'Red Miss',
#   '2017',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-hamlet-1913-online',
#   'Hamlet',
#   '1913',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-railways-for-ever-1970-online',
#   'Railways for Ever!',
#   '1970',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-wisdom-of-the-wild-1940-online',
#   'Wisdom of the Wild',
#   '1940',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-pattern-for-progress-1948-online',
#   'Pattern for Progress',
#   '1948',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-miner-1950-online',
#   'Miner',
#   '1950',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-caefelin-laundry-llangollen-1937-online',
#   'Caefelin Laundry, Llangollen',
#   '1937',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-ship-is-launched-1957-online',
#   'Ship is Launched',
#   '1957',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-west-sussex-home-guard-1-1941-online',
#   'West Sussex Home Guard 1',
#   '1941',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-screenwriter-tess-morris-on-how-to-write-a-romcom-online',
#   'Screenwriter Tess Morris on how to write a romcom',
#   '0',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-a-trip-to-the-moon-1902-online',
#   'A Trip to the Moon',
#   '1902',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-vote-for-froglet-1974-online',
#   'Vote for Froglet',
#   '1974',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-bradford-godfather-1976-online',
#   'The Bradford Godfather',
#   '0',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-hints-and-hobbies-no11-1926-online',
#   'Hints and Hobbies No.11',
#   '1926',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-from-hk-to-mk-2017-online',
#   'From HK to MK',
#   '2017',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-listen-to-britain-1942-online',
#   'Listen to Britain',
#   '1942',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-destructors-1983-online',
#   'The Destructors',
#   '1983',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-perfect-woman-1949-online',
#   'The Perfect Woman',
#   '1949',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-out-of-the-rubble-2015-online',
#   'Out of the Rubble',
#   '2015',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-conquest-of-everest-1953-online',
#   'The Conquest of Everest',
#   '1953',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-vote-for-froglet-1974-online',
#   'Vote for Froglet',
#   '1974',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-the-somme-1927-online',
#   'The Somme',
#   '1927',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-refugee-today-and-tomorrow-1938-online',
#   'Refugee Today and Tomorrow',
#   '1938',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-london-street-scenes-trafalgar-square-1910-online',
#   'London Street Scenes - Trafalgar Square',
#   '1910',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-francis-bacon-paintings-1944-1962-1963-online',
#   'Francis Bacon: Paintings 1944-1962',
#   '1963',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-queens-visit-to-newcastle-1954-fa-cup-returns-1955-1954-online',
#   'Queens Visit to Newcastle 1954: FA Cup Returns 1955',
#   '1954',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-around-the-village-green-1937-online',
#   'Around the Village Green',
#   '1937',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-milton-keynes-a-village-city-1973-online',
#   'Milton Keynes - A Village City',
#   '1973',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-china-on-film-an-introduction-2014-online',
#   'China on Film - an introduction',
#   '2014',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-dear-murderer-1947-online',
#   'Dear Murderer',
#   '1947',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-carlito-se-va-para-siempre-2018-online',
#   'Carlito se va para siempre',
#   '2018',
#   '',
#   'bfi'],
#  ['https://player.bfi.org.uk/free/film/watch-funeral-at-the-front-1915-online',
#   'Funeral at the Front',
#   '1915',
#   '',
#   'bfi'],
#  ['', '1 Chance 2 Dance', '2014', '', 'netflix'],
#  ['', '1 Mile to You', '2017', '', 'netflix'],
#  ['', '10 jours en or', '2012', '', 'netflix'],
#  ['', "The 10 Sins (Al khataya al a'ashr)", '2018', '', 'netflix'],
#  ['', '100 Metros', '2016', '', 'netflix'],
#  ['', 'The 100 Years Show', '2015', '', 'netflix'],
#  ['', '100% Hotter', '2017', '', 'netflix'],
#  ['', '1000 Rupee Note', '2014', '', 'netflix'],
#  ['',
#   'The 101-Year-Old Man Who Skipped Out on the Bill and Disappeared',
#   '2016',
#   '',
#   'netflix'],
#  ['', '12 Years Promise', '2014', '', 'netflix'],
#  ['', 'The 12th Man', '2018', '', 'netflix'],
#  ['', '13 Reasons Why', '2018', '', 'netflix'],
#  ['', '13 Reasons Why: Beyond the Reasons', '2018', '', 'netflix'],
#  ['', '13TH', '2016', '', 'netflix'],
#  ['',
#   '13TH: A Conversation with Oprah Winfrey and Ava DuVernay',
#   '2017',
#   '',
#   'netflix'],
#  ['', '14 Minutes from Earth', '2016', '', 'netflix'],
#  ['', '15 August', '2019', '', 'netflix'],
#  ['', '1920', '2008', '', 'netflix'],
#  ['', '1920 London', '2016', '', 'netflix'],
#  ['', '1922', '2017', '', 'netflix'],
#  ['', '1983', '2018', '', 'netflix'],
#  ['', '1994', '2019', '', 'netflix'],
#  ['', '2 Guns', '2013', '', 'netflix'],
#  ['', '2 States', '2014', '', 'netflix'],
#  ['', '2 Weeks', '2013', '', 'netflix'],
#  ['', '2,215', '2018', '', 'netflix'],
#  ['', '20 Minutes (20 Dakika)', '2013', '', 'netflix'],
#  ['', '2015 Dream Concert', '2015', '', 'netflix'],
#  ['', '20th Century Women', '2016', '', 'netflix'],
#  ['', '21', '2008', '', 'netflix'],
#  ['', '21 & Over', '2013', '', 'netflix'],
#  ['', '21 Jump Street', '2012', '', 'netflix'],
#  ['', '21 Sarfarosh: Saragarhi 1897', '2018', '', 'netflix'],
#  ['', '21 Thunder', '2017', '', 'netflix'],
#  ['', '211', '2018', '', 'netflix'],
#  ['', '22 July', '2018', '', 'netflix'],
#  ['', '23:59', '2011', '', 'netflix'],
#  ['', '24 Hours to Live', '2017', '', 'netflix'],
#  ['', '25 Kille', '2016', '', 'netflix'],
#  ['', '26 Years', '2012', '', 'netflix'],
#  ['', '27: Gone Too Soon', '2017', '', 'netflix'],
#  ['', '28 Moons', '2016', '', 'netflix'],
#  ['', '3 Days to Kill', '2014', '', 'netflix'],
#  ['', '3 Heroines (3 Srikandi)', '2016', '', 'netflix'],
#  ['', '3 Idiots', '2009', '', 'netflix'],
#  ['', '3 Seconds Divorce', '2018', '', 'netflix'],
#  ['', '3 Türken & ein Baby', '2015', '', 'netflix'],
#  ['', '3%', '2019', '', 'netflix'],
#  ['', '30 Days of Luxury (Talatin Yom fi el-Izz)', '2016', '', 'netflix'],
#  ['', '30 Minutes or Less', '2011', '', 'netflix'],
#  ['', '3096 Tage', '2013', '', 'netflix'],
#  ['', 'The 34th', '2017', '', 'netflix'],
#  ['', 'The 36th Chamber Of Shaolin', '1978', '', 'netflix'],
#  ['', '3Below: Tales of Arcadia', '2018', '', 'netflix'],
#  ['', 'The 3rd Eye 2', '2019', '', 'netflix'],
#  ['', 'The 3rd Eye (Mata Batin)', '2018', '', 'netflix'],
#  ['', '42 Grams', '2017', '', 'netflix'],
#  ['', 'The 43', '2019', '', 'netflix'],
#  ['', '45 rpm (45 Revoluciones)', '2019', '', 'netflix'],
#  ['', '46', '2016', '', 'netflix'],
#  ['', '47 Metres Down', '2016', '', 'netflix'],
#  ['', '47 Ronin', '2013', '', 'netflix'],
#  ['', '48 Christmas Wishes', '2017', '', 'netflix'],
#  ['', '49 Days', '2011', '', 'netflix'],
#  ['', '4L (4 Latas)', '2019', '', 'netflix'],
#  ['', 'The 4th Company (La 4ª Compañía)', '2016', '', 'netflix'],
#  ['', '4th Man Out', '2015', '', 'netflix'],
#  ['', '5 Cowok Jagoan', '2017', '', 'netflix'],
#  ['', '5 Star Christmas (Natale a 5 Stelle)', '2018', '', 'netflix'],
#  ['', '50 First Dates', '2004', '', 'netflix'],
#  ['', '5CM', '2012', '', 'netflix'],
#  ['', '6 Balloons', '2018', '', 'netflix'],
#  ['', '6 Days', '2017', '', 'netflix'],
#  ['', '6 Years', '2015', '', 'netflix'],
#  ['', '6-5=2', '2014', '', 'netflix'],
#  ['', 'The 6th Day', '2000', '', 'netflix'],
#  ['', '7 (Seven)', '2019', '', 'netflix'],
#  ['', '7 años', '2016', '', 'netflix'],
#  ['', '7 Days Out', '2018', '', 'netflix'],
#  ['', '7 Din Mohabbat In (Love in 7 Days)', '2018', '', 'netflix'],
#  ['', '7 Khoon Maaf', '2011', '', 'netflix'],
#  ['', '706', '2019', '', 'netflix'],
#  ['', '72 Cutest Animals', '2016', '', 'netflix'],
#  ['', '72 Dangerous Animals: Asia', '2018', '', 'netflix'],
#  ['', '72 Dangerous Animals: Latin America', '2017', '', 'netflix'],
#  ['', '72 Dangerous Places', '2016', '', 'netflix'],
#  ['', '77 Heartbreaks', '2017', '', 'netflix'],
#  ['', '7:19', '2016', '', 'netflix'],
#  ['', '7SEEDS', '2019', '', 'netflix'],
#  ['', '8 Mile', '2002', '', 'netflix'],
#  ['', '90 ML', '2019', '', 'netflix'],
#  ['', '99', '2009', '', 'netflix'],
#  ['', 'A 2nd Chance', '2011', '', 'netflix'],
#  ['', 'A Beautiful Life', '2011', '', 'netflix'],
#  ['', 'A Billion Colour Story', '2016', '', 'netflix'],
#  ['', 'A Bit of Fry and Laurie', '1995', '', 'netflix'],
#  ['', 'A Boy Name Flora A', '2017', '', 'netflix'],
#  ['', 'A Christmas Prince', '2017', '', 'netflix'],
#  ['', 'A Christmas Prince: The Royal Wedding', '2018', '', 'netflix'],
#  ['', 'A Cure for Wellness', '2016', '', 'netflix'],
#  ['', "A Dog's Life", '2013', '', 'netflix'],
#  ['', 'A Family Affair', '2015', '', 'netflix'],
#  ['', 'A Family Man', '2016', '', 'netflix'],
#  ['', 'A Few Less Men', '2017', '', 'netflix'],
#  ['', 'A Fish Called Wanda', '1988', '', 'netflix'],
#  ['', 'A Fistful of Dollars', '1964', '', 'netflix'],
#  ['', 'A Flying Jatt', '2016', '', 'netflix'],
#  ['', 'A Fortunate Man', '2018', '', 'netflix'],
#  ['', 'A Futile and Stupid Gesture', '2018', '', 'netflix'],
#  ['', 'A Ghost Story', '2017', '', 'netflix'],
#  ['',
#   'A Good Wife (Qin ai de, wo ai shang bie ren le)',
#   '2013',
#   '',
#   'netflix'],
#  ['', 'A Grand Night In: The Story of Aardman', '2015', '', 'netflix'],
#  ['', 'A Gray State', '2017', '', 'netflix'],
#  ['', 'A Guy Thing', '2003', '', 'netflix'],
#  ['', 'A Heavy Heart', '2015', '', 'netflix'],
#  ['', 'A Home of Our Own', '1993', '', 'netflix'],
#  ['', 'A Home with A View', '2019', '', 'netflix'],
#  ['', 'A House of Blocks', '2017', '', 'netflix'],
#  ['', 'A Kid Like Jake', '2018', '', 'netflix'],
#  ['', "A Knight's Tale", '2001', '', 'netflix'],
#  ['', 'A Korean Odyssey (Hwayugi)', '2017', '', 'netflix'],
#  ['', 'A Land Imagined', '2019', '', 'netflix'],
#  ['', 'A Little Help with Carol Burnett', '2018', '', 'netflix'],
#  ['', 'A Long Way Home', '2003', '', 'netflix'],
#  ['',
#   'A Love So Beautiful (Zhi Wo Men Dan Chun De Xiao Mei Hao)',
#   '2017',
#   '',
#   'netflix'],
#  ['', 'A Love Story', '2007', '', 'netflix'],
#  ['', 'A Man Called God', '2010', '', 'netflix'],
#  ['', "A Midsummer Night's Sex Comedy", '1982', '', 'netflix'],
#  ['', 'A mighty Team (La Dream Team)', '2016', '', 'netflix'],
#  ['', 'A Million Ways to Die in the West', '2014', '', 'netflix'],
#  ['', 'A Mission in an Old Movie', '2012', '', 'netflix'],
#  ['', 'A Moody Christmas', '2012', '', 'netflix'],
#  ['', 'A Most Violent Year', '2014', '', 'netflix'],
#  ['', 'A New Capitalism (Um Novo Capitalismo)', '2017', '', 'netflix'],
#  ['', 'A Noble Intention (Publieke werken)', '2015', '', 'netflix'],
#  ['', 'A Perfect Day', '2015', '', 'netflix'],
#  ['', 'A Prayer for the Dying', '1987', '', 'netflix'],
#  ['', 'A Royal Affair (En kongelig affære)', '2012', '', 'netflix'],
#  ['', 'A Russell Peters Christmas', '2011', '', 'netflix'],
#  ['', 'A Scandall', '2016', '', 'netflix'],
#  ['', 'A Second Chance', '2015', '', 'netflix'],
#  ['', 'A Series of Unfortunate Events', '2019', '', 'netflix'],
#  ['', 'A Shot in the Dark', '1964', '', 'netflix'],
#  ['', 'A Silent Voice', '2016', '', 'netflix'],
#  ['', 'A Simple Favour', '2018', '', 'netflix'],
#  ['', "A Soldier's Story", '2015', '', 'netflix'],
#  ['', 'A Sort of Family', '2017', '', 'netflix'],
#  ['', 'A Star Is Born (1976)', '1976', '', 'netflix'],
#  ['', 'A StoryBots Christmas', '2017', '', 'netflix'],
#  ['', 'A Suitable Girl', '2017', '', 'netflix'],
#  ['', 'A Taiwanese Tale of Two Cities', '2018', '', 'netflix'],
#  ['', 'A Tale of Two Kitchens', '2019', '', 'netflix'],
#  ['', 'A Thousand Goodnights', '2019', '', 'netflix'],
#  ['', 'A Touch of Green', '2016', '', 'netflix'],
#  ['', "A Turtle's Tale: Sammy's Adventures", '2010', '', 'netflix'],
#  ['', 'A Twelve Year Night (La noche de 12 años)', '2018', '', 'netflix'],
#  ['', 'A Very Murray Christmas', '2015', '', 'netflix'],
#  ['', 'A Very Secret Service', '2015', '', 'netflix'],
#  ['', 'A Violent Man', '2017', '', 'netflix'],
#  ['', 'A Walk Among the Tombstones', '2014', '', 'netflix'],
#  ['', 'A Wednesday', '2008', '', 'netflix'],
#  ['', 'A Week in Watts', '2017', '', 'netflix'],
#  ['', 'A Wish for Christmas', '2016', '', 'netflix'],
#  ['', "A Witches' Ball", '2017', '', 'netflix'],
#  ['', 'A YELLOW BIRD', '2016', '', 'netflix'],
#  ['',
#   'Aşk Tesadüfleri Sever (Love Loves Coincidences)',
#   '2011',
#   '',
#   'netflix'],
#  ['', 'A.D. Kingdom and Empire', '2015', '', 'netflix'],
#  ['', 'A.I.C.O. (A.I.C.O. Incarnation)', '2018', '', 'netflix'],
#  ['', 'Aadu 2', '2017', '', 'netflix'],
#  ['', 'Aagey Se Right', '2009', '', 'netflix'],
#  ['', 'Aajcha Divas Majha', '2013', '', 'netflix'],
#  ['', 'Aakhri Adaalat', '1988', '', 'netflix'],
#  ['', 'Aalorukkam', '2018', '', 'netflix'],
#  ['', 'Aamir', '2008', '', 'netflix'],
#  ['', 'Aashayein', '2010', '', 'netflix'],
#  ['', 'Aashik Awara', '1993', '', 'netflix'],
#  ['', 'Aata Pita', '2010', '', 'netflix'],
#  ['', 'Abby Sen', '2015', '', 'netflix'],
#  ['', 'ABCD 2', '2015', '', 'netflix'],
#  ['', 'ABCD: Any Body Can Dance', '2013', '', 'netflix'],
#  ['', 'Abdo Mota (Abdu Mouta)', '2012', '', 'netflix'],
#  ['', 'Abducted in Plain Sight', '2017', '', 'netflix'],
#  ['', 'Abduction', '2011', '', 'netflix'],
#  ['', 'Abdullah, The Final Witness', '2016', '', 'netflix'],
#  ['', 'Abhinetri', '2016', '', 'netflix'],
#  ['', 'Abnormal Summit', '2017', '', 'netflix'],
#  ['', 'About Time', '2013', '', 'netflix'],
#  ['', 'Absolutely Fabulous', '2012', '', 'netflix'],
#  ['', 'Abstract: The Art of Design', '2017', '', 'netflix'],
#  ['', 'Abyss', '2019', '', 'netflix'],
#  ['', 'Abzurdah', '2015', '', 'netflix'],
#  ['', 'Acapulco La vida va', '2016', '', 'netflix'],
#  ['', 'Accident', '2009', '', 'netflix'],
#  ['', 'Accidentally in Love', '2018', '', 'netflix'],
#  ['', 'The Accountant of Auschwitz', '2018', '', 'netflix'],
#  ['', 'The Accountant', '2016', '', 'netflix'],
#  ['', 'Ace Ventura: Pet Detective', '1994', '', 'netflix'],
#  ['', 'Ace Ventura: When Nature Calls', '1995', '', 'netflix'],
#  ['', 'Across Grace Alley', '2013', '', 'netflix'],
#  ['', 'Act of Valour', '2012', '', 'netflix'],
#  ['', 'Act of Vengeance', '2010', '', 'netflix'],
#  ['', 'Action Replayy', '2010', '', 'netflix'],
#  ['', 'Acts of Vengeance', '2017', '', 'netflix'],
#  ['', 'Acts of Violence', '2018', '', 'netflix'],
#  ['', 'Adam Devine: Best Time of Our Lives', '2019', '', 'netflix'],
#  ['', 'ADAM SANDLER 100% FRESH', '2018', '', 'netflix'],
#  ['', 'Adel Karam: Live from Beirut', '2018', '', 'netflix'],
#  ['', 'Adhugo', '2018', '', 'netflix'],
#  ['', "Aditi Mittal: Things They Wouldn't Let Me Say", '2017', '', 'netflix'],
#  ['', 'The Adjusters', '2010', '', 'netflix'],
#  ['', 'The Adjustment Bureau', '2011', '', 'netflix'],
#  ['', 'Adrift', '2018', '', 'netflix'],
#  ['', 'Advantageous', '2015', '', 'netflix'],
#  ['', 'The Adventure Club', '2016', '', 'netflix'],
#  ['', 'Adventureland', '2009', '', 'netflix'],
#  ['', 'The Adventures of Figaro Pho', '2015', '', 'netflix'],
#  ['', 'The Adventures of Puss in Boots', '2018', '', 'netflix'],
#  ['', 'The Adventures of Sharkboy & Lavagirl', '2005', '', 'netflix'],
#  ['', 'The Adventures of Super Mario Bros. 3', '1990', '', 'netflix'],
#  ['', 'The Adventures of the American Rabbit', '1986', '', 'netflix'],
#  ['', 'The Adventures of Tintin', '1992', '', 'netflix'],
#  ['', 'Afflicted', '2018', '', 'netflix'],
#  ['', 'Africa', '2013', '', 'netflix'],
#  ['', 'The African Doctor', '2016', '', 'netflix'],
#  ['', 'After', '2019', '', 'netflix'],
#  ['', 'After Life', '2019', '', 'netflix'],
#  ['', 'After Maria', '2019', '', 'netflix'],
#  ['', 'The After Party', '2018', '', 'netflix'],
#  ['', 'After Porn Ends', '2012', '', 'netflix'],
#  ['', 'After Porn Ends 3', '2017', '', 'netflix'],
#  ['', 'After Trek', '2017', '', 'netflix'],
#  ['', 'Agadbam', '2010', '', 'netflix'],
#  ['', 'Again Kasargod Khader Bai', '2010', '', 'netflix'],
#  ['', 'Against The Tide', '2014', '', 'netflix'],
#  ['', 'Agatha and the Truth of Murder', '2018', '', 'netflix'],
#  ['', "Agatha Christie's Crooked House", '2017', '', 'netflix'],
#  ['', 'Age of Glory', '2010', '', 'netflix'],
#  ['', 'Age of Rebellion', '2018', '', 'netflix'],
#  ['', 'Age of Tanks', '2017', '', 'netflix'],
#  ['', 'Agent Cody Banks 2: Destination London', '2004', '', 'netflix'],
#  ['', 'Agent Raghav', '2015', '', 'netflix'],
#  ['', 'Aggretsuko', '2018', '', 'netflix'],
#  ['', 'Aggretsuko: We Wish You a Metal Christmas', '2018', '', 'netflix'],
#  ['', 'Agustín Aristarán: Soy Rada', '2018', '', 'netflix'],
#  ['', 'Agyaat', '2009', '', 'netflix'],
#  ['', 'Ainori Love Wagon: Asian Journey', '2018', '', 'netflix'],
#  ['', 'Air Bud: Spikes Back', '2003', '', 'netflix'],
#  ['', 'Air Bud: World Pup', '2000', '', 'netflix'],
#  ['', 'Air Buddies', '2006', '', 'netflix'],
#  ['', 'Aisa Yeh Jahaan (The World It Is)', '2015', '', 'netflix'],
#  ['', 'Aitraaz', '2004', '', 'netflix'],
#  ['', 'Aiyaary', '2018', '', 'netflix'],
#  ['', 'Aiyyaa', '2012', '', 'netflix'],
#  ['', 'Ajaibnya Cinta', '2015', '', 'netflix'],
#  ['', 'AJIN: Demi-Human', '2016', '', 'netflix'],
#  ['', 'Ajji', '2017', '', 'netflix'],
#  ['', 'Akulah Balqis', '2015', '', 'netflix'],
#  ['', 'Al Hayba', '2017', '', 'netflix'],
#  ['', 'Al Pitcher - Fy Fan Sweden!', '2017', '', 'netflix'],
#  ['', 'Alan Saldaña: Mi vida de pobre', '2017', '', 'netflix'],
#  ['', 'Alarmoty in the Land of Fire', '2017', '', 'netflix'],
#  ['', 'Albion: The Enchanted Stallion', '2016', '', 'netflix'],
#  ['', 'The Alcàsser Murders', '2019', '', 'netflix'],
#  ['', 'Alejandro Riaño: Especial de stand up', '2018', '', 'netflix'],
#  ['', 'Alejandro Sanz: What I Was Is What I Am', '2018', '', 'netflix'],
#  ['', 'Alex Strangelove', '2018', '', 'netflix'],
#  ['', 'Alexa & Katie', '2018', '', 'netflix'],
#  ['', 'Alexis Viera: A Story of Surviving', '2019', '', 'netflix'],
#  ['', 'Ali Baba ve 7 Cüceler', '2015', '', 'netflix'],
#  ['', 'Ali Wong: Baby Cobra', '2016', '', 'netflix'],
#  ['', 'Ali Wong: Hard Knock Wife', '2018', '', 'netflix'],
#  ['', "Ali's Wedding", '2018', '', 'netflix'],
#  ['', 'Alias Grace', '2017', '', 'netflix'],
#  ['',
#   'Alias JJ, la celebridad del mal (Alias JJ, The Celebrity of Evil)',
#   '2017',
#   '',
#   'netflix'],
#  ['', 'Alibaba Aur 40 Chor', '1980', '', 'netflix'],
#  ['', 'Alien Autopsy: Fact or Fiction?', '1995', '', 'netflix'],
#  ['', 'Alien Contact: Outer Space', '2017', '', 'netflix'],
#  ['', 'Alien Mummies', '2012', '', 'netflix'],
#  ['', 'Alien Warfare', '2016', '', 'netflix'],
#  ['', 'The Alienist', '2018', '', 'netflix'],
#  ['', 'Alive and Kicking', '2016', '', 'netflix'],
#  ['', 'All About Love', '2017', '', 'netflix'],
#  ['', 'All About the Washingtons', '2018', '', 'netflix'],
#  ['', 'All Hail King Julien', '2017', '', 'netflix'],
#  ['', 'All Hail King Julien: Exiled', '2017', '', 'netflix'],
#  ['', 'All Hail King Julien: Happy Birthday to You!', '2017', '', 'netflix'],
#  ['', "All Hallows' Eve", '2016', '', 'netflix'],
#  ['', 'All I See Is You', '2016', '', 'netflix'],
#  ['', 'All In My Family', '2019', '', 'netflix'],
#  ['', 'All Is Lost', '2013', '', 'netflix'],
#  ['', 'All of You', '2017', '', 'netflix'],
#  ['', "All the Devil's Men", '2018', '', 'netflix'],
#  ['',
#   'All The Reasons To Forget (Todas As Razões Para Esquecer)',
#   '2017',
#   '',
#   'netflix'],
#  ['', 'Alles ist gut (All Is Good)', '2019', '', 'netflix'],
#  ['', 'Almost Friends', '2017', '', 'netflix'],
#  ['', 'Almost Royal', '2016', '', 'netflix'],
#  ['', 'Aloha', '2015', '', 'netflix'],
#  ['', 'Alpha and Omega', '2010', '', 'netflix'],
#  ['', 'AlphaGo', '2017', '', 'netflix'],
#  ['', 'Altered Carbon', '2018', '', 'netflix'],
#  ['', 'Alvin and the Chipmunks: The Road Chip', '2015', '', 'netflix'],
#  ['', 'ALVINNN!!! And the Chipmunks', '2016', '', 'netflix'],
#  ['', 'Always a Witch (Siempre Bruja)', '2019', '', 'netflix'],
#  ['', 'Always Be My Maybe', '2019', '', 'netflix'],
#  ['', 'Amanda Knox', '2016', '', 'netflix'],
#  ['', 'Amar', '2017', '', 'netflix'],
#  ['', 'Amar Akbar & Tony', '2015', '', 'netflix'],
#  ['', "Amar's Hands (Kaf alqamar)", '2011', '', 'netflix'],
#  ['', 'Amateur', '2018', '', 'netflix'],
#  ['', 'Amazing Interiors', '2018', '', 'netflix'],
#  ['', 'The Amazing Praybeyt Benjamin', '2014', '', 'netflix'],
#  ['', "America's Got Talent", '2019', '', 'netflix'],
#  ['', "America's Got Talent: The Champions", '2019', '', 'netflix'],
#  ['', 'American Anarchist', '2016', '', 'netflix'],
#  ['', 'American Assassin', '2017', '', 'netflix'],
#  ['', 'American Circumcision', '2017', '', 'netflix'],
#  ['', 'The American Dream Project', '2015', '', 'netflix'],
#  ['', 'American Experience: The Circus', '2018', '', 'netflix'],
#  ['', 'American Experience: The Island Murder', '2018', '', 'netflix'],
#  ['', 'American Gangster', '2007', '', 'netflix'],
#  ['', 'American Horror Story', '2017', '', 'netflix'],
#  ['', 'American Idol', '2019', '', 'netflix'],
#  ['', 'American Made', '2017', '', 'netflix'],
#  ['', 'The American Meme', '2018', '', 'netflix'],
#  ['', 'American Ninja 4: The Annihilation', '1991', '', 'netflix'],
#  ['', 'American Pie', '1999', '', 'netflix'],
#  ['', 'American Pie 2', '2001', '', 'netflix'],
#  ['', 'American Pie Presents: Band Camp', '2005', '', 'netflix'],
#  ['', 'American Pie Presents: Beta House', '2007', '', 'netflix'],
#  ['', 'American Poltergeist', '2015', '', 'netflix'],
#  ['', 'American Psycho', '2000', '', 'netflix'],
#  ['', 'American Reunion', '2012', '', 'netflix'],
#  ['', 'American Vandal', '2018', '', 'netflix'],
#  ['', 'Amnesia', '2015', '', 'netflix'],
#  ['', 'AMO', '2017', '', 'netflix'],
#  ['', 'Among Family (Aile Arasinda)', '2017', '', 'netflix'],
#  ['', 'Amrapali', '1966', '', 'netflix'],
#  ['', 'Amy Schumer Growing', '2019', '', 'netflix'],
#  ['', 'Amy Schumer: The Leather Special', '2017', '', 'netflix'],
#  ['', 'An American in Madras', '2013', '', 'netflix'],
#  ['', 'An Evening with Beverly Luff Linn', '2018', '', 'netflix'],
#  ['', "An Hour and a Half (Saa'a wi Nos)", '2012', '', 'netflix'],
#  ['', 'An Immortal Classic', '2012', '', 'netflix'],
#  ['', 'An Innocent Mistake', '2012', '', 'netflix'],
#  ['', 'An Inspector Calls', '2015', '', 'netflix'],
#  ['', 'An Upper Egyptian (Wahid Saeiday)', '2014', '', 'netflix'],
#  ['', 'Anaarkali of Aarah', '2017', '', 'netflix'],
#  ['', 'And Breathe Normally', '2018', '', 'netflix'],
#  ['', 'Andaz Apna Apna', '1994', '', 'netflix'],
#  ['', 'Andhadhun', '2018', '', 'netflix'],
#  ['', 'Angamaly Diaries', '2017', '', 'netflix'],
#  ['', "Angel 'N' Devil", '2014', '', 'netflix'],
#  ['', 'Angel Beats', '2010', '', 'netflix'],
#  ['', 'Angel of Christmas', '2015', '', 'netflix'],
#  ['', 'The Angel', '2018', '', 'netflix'],
#  ['', "Angela's Christmas", '2018', '', 'netflix'],
#  ['', 'Anger Management', '2003', '', 'netflix'],
#  ['', 'Angry Birds', '2018', '', 'netflix'],
#  ['', 'The Angry Birds Movie', '2016', '', 'netflix'],
#  ['', 'Angry Indian Goddesses', '2015', '', 'netflix'],
#  ['', 'Angry Mom', '2015', '', 'netflix'],
#  ['', 'Angus, Thongs and Perfect Snogging', '2008', '', 'netflix'],
#  ['', 'ANIMA', '2019', '', 'netflix'],
#  ['', 'Animal World', '2018', '', 'netflix'],
#  ['', 'Animas', '2018', '', 'netflix'],
#  ['', 'Animism', '2013', '', 'netflix'],
#  ['', 'Anjaan', '2014', '', 'netflix'],
#  ['', 'Anjaan: Rural Myths', '2018', '', 'netflix'],
#  ['', 'Anjaan: Special Crimes Unit', '2018', '', 'netflix'],
#  ['', 'Anjelah Johnson: Not Fancy', '2015', '', 'netflix'],
#  ['', 'Ankur Arora Murder Case', '2013', '', 'netflix'],
#  ['', 'Annabelle Hooper And The Ghosts Of Nantucket', '2016', '', 'netflix'],
#  ['', 'Annayum Rasoolum', '2013', '', 'netflix'],
#  ['', 'Anne with an E', '2018', '', 'netflix'],
#  ['', 'Annie', '1982', '', 'netflix'],
#  ['', 'Annie', '2014', '', 'netflix'],
#  ['', 'Annihilation', '2018', '', 'netflix'],
#  ['', 'Anohana: The Flower We Saw That Day', '2011', '', 'netflix'],
#  ['', 'The Anomaly', '2014', '', 'netflix'],
#  ['', 'Another Forever', '2016', '', 'netflix'],
#  ['', 'Another Life', '2019', '', 'netflix'],
#  ['', 'Answer for Heaven', '2019', '', 'netflix'],
#  ['', "The Ant's Scream (Ant Scream)", '2010', '', 'netflix'],
#  ['', 'Ant-Man', '2015', '', 'netflix'],
#  ['',
#   'Antar: Son of Shadad (Antar Ibn Ibn Ibn Shaddad)',
#   '2017',
#   '',
#   'netflix'],
#  ['', 'Antariksha Ke Rakhwale', '2018', '', 'netflix'],
#  ['', 'Anthony Jeselnik: Fire in the Maternity Ward', '2019', '', 'netflix'],
#  ['', 'Anthony Jeselnik: Thoughts and Prayers', '2015', '', 'netflix'],
#  ['', 'Anthony Kaun Hai?', '2006', '', 'netflix'],
#  ['', 'Antoine Griezmann: The Making of a Legend', '2019', '', 'netflix'],
#  ['', 'Apaches', '2016', '', 'netflix'],
#  ['', 'The Apartment', '2014', '', 'netflix'],
#  ['', 'APEX: The Story of the Hypercar', '2016', '', 'netflix'],
#  ['', 'Apollo 13', '1995', '', 'netflix'],
#  ['', 'The Apostate (El apóstata)', '2015', '', 'netflix'],
#  ['', 'Apostle', '2018', '', 'netflix'],
#  ['', 'Approaching the Unknown', '2016', '', 'netflix'],
#  ['', 'Aquarius', '2016', '', 'netflix'],
#  ['', 'Aquarius', '2016', '', 'netflix'],
#  ['', 'Aram, Aram', '2015', '', 'netflix'],
#  ['', 'Arango y Sanint: Ríase el show', '2018', '', 'netflix'],
#  ['', 'The Arbitration', '2016', '', 'netflix'],
#  ['', 'Archer', '2019', '', 'netflix'],
#  ['', 'Arctic Heart', '2016', '', 'netflix'],
#  ['', 'Are We Done Yet?', '2018', '', 'netflix'],
#  ['', 'Are We There Yet?', '2005', '', 'netflix'],
#  ['', 'Are You Human', '2018', '', 'netflix'],
#  ['', 'Arena', '1989', '', 'netflix'],
#  ['', 'Ares', '2016', '', 'netflix'],
#  ['', 'Argon', '2017', '', 'netflix'],
#  ['', 'Ari Shaffir: Double Negative', '2017', '', 'netflix'],
#  ['', 'Arisan 2', '2011', '', 'netflix'],
#  ['', 'Arjun: The Warrior Prince', '2011', '', 'netflix'],
#  ['', 'Armed Response', '2017', '', 'netflix'],
#  ['', 'Armistice', '2008', '', 'netflix'],
#  ['', 'Arnez J: Racially Motivated', '2013', '', 'netflix'],
#  ['', 'Aroni Takhon', '2017', '', 'netflix'],
#  ['', 'ARQ', '2016', '', 'netflix'],
#  ['', 'Arrested Development', '2019', '', 'netflix'],
#  ['', 'The Art of Loving', '2017', '', 'netflix'],
#  ['', 'The Art of Organized Noize', '2016', '', 'netflix'],
#  ['', 'Arthdal Chronicles', '2019', '', 'netflix'],
#  ['', 'Arthur Christmas', '2011', '', 'netflix'],
#  ['', 'As Above, So Below', '2014', '', 'netflix'],
#  ['', 'As the Light Goes Out', '2014', '', 'netflix'],
#  ['', 'Asamapta (Incomplete)', '2017', '', 'netflix'],
#  ['', 'Ascension', '2014', '', 'netflix'],
#  ['', 'Ascharyachakit! (Ascharya F**k It )', '2018', '', 'netflix'],
#  ['', 'Asees', '2018', '', 'netflix'],
#  ['', 'Ash vs. Evil Dead', '2015', '', 'netflix'],
#  ['', 'Ashby', '2015', '', 'netflix'],
#  ['', 'Ashes of Love', '2018', '', 'netflix'],
#  ['', 'Asian Provocateur', '2016', '', 'netflix'],
#  ['', 'Ask the Doctor', '2017', '', 'netflix'],
#  ['', 'Ask the StoryBots', '2019', '', 'netflix'],
#  ['', 'Asoka (Ashoka the Great)', '2001', '', 'netflix'],
#  ['', "Asperger's Are Us", '2016', '', 'netflix'],
#  ['', 'The Assassination of Gianni Versace', '2018', '', 'netflix'],
#  ['', 'The Asterisk War', '2015', '', 'netflix'],
#  ['', 'Asterix the Gaul', '1967', '', 'netflix'],
#  ['', 'Asterix: The 12 Tasks', '1976', '', 'netflix'],
#  ['', 'Astral', '2018', '', 'netflix'],
#  ['', 'At All Costs', '2016', '', 'netflix'],
#  ['', 'At First Sight', '1999', '', 'netflix'],
#  ['', 'Atelier (Underwear)', '2015', '', 'netflix'],
#  ['', 'ATM (ATM: Er Rak Error)', '2012', '', 'netflix'],
#  ['', 'Atomic Blonde', '2017', '', 'netflix'],
#  ['', 'Attack on Titan', '2013', '', 'netflix'],
#  ['', 'Attack the Block', '2011', '', 'netflix'],
#  ['',
#   'Attacking the Devil: Harold Evans and the Last Nazi War Crime',
#   '2014',
#   '',
#   'netflix'],
#  ['', 'Attention, Love!', '2017', '', 'netflix'],
#  ['', 'Attitude Test (Prueba de Actitud)', '2016', '', 'netflix'],
#  ['', 'Atypical', '2018', '', 'netflix'],
#  ['', 'Audrey Rose', '1977', '', 'netflix'],
#  ['', 'Audrie & Daisy', '2016', '', 'netflix'],
#  ['', 'Aurora', '2018', '', 'netflix'],
#  ['', 'Aus dem Nichts (In The Fade)', '2017', '', 'netflix'],
#  ['', 'Auschwitz: The Nazis and the Final Solution', '2005', '', 'netflix'],
#  ['', 'Austin Powers: The Spy Who Shagged Me', '1999', '', 'netflix'],
#  ['', 'Autohead', '2016', '', 'netflix'],
#  ['', 'Autumn Dreams', '2015', '', 'netflix'],
#  ['', "Autumn's Concerto", '2009', '', 'netflix'],
#  ['', 'Aval (The House Next Door)', '2017', '', 'netflix'],
#  ['', 'Avec Eric', '2016', '', 'netflix'],
#  ['', 'Await Further Instructions', '2018', '', 'netflix'],
#  ['', 'Awake: The Million Dollar Game', '2019', '', 'netflix'],
#  ['', 'Awaken the Shadowman', '2017', '', 'netflix'],
#  ['', 'Away From Home', '2015', '', 'netflix'],
#  ['', 'Awe', '2018', '', 'netflix'],
#  ['', '¡Ay, mi madre!', '2019', '', 'netflix'],
#  ['', 'Ayana', '2017', '', 'netflix'],
#  ['', 'Ayotzinapa, el paso de la tortuga', '2018', '', 'netflix'],
#  ['', 'Azhar', '2016', '', 'netflix'],
#  ['', 'Aziz Ansari Live at Madison Square Garden', '2015', '', 'netflix'],
#  ['', 'Aziz Ansari: Buried Alive', '2013', '', 'netflix'],
#  ['', 'Aziz Ansari: RIGHT NOW', '2019', '', 'netflix'],
#  ['', 'Çarsi Pazar', '2015', '', 'netflix'],
#  ['', 'Çok Filim Hareketler Bunlar', '2010', '', 'netflix'],
#  ['',
#   "The B-Side: Elsa Dorfman's Portrait Photography",
#   '2016',
#   '',
#   'netflix'],
#  ['', 'B.A. Pass', '2013', '', 'netflix'],
#  ['', 'B.A. Pass 2', '2017', '', 'netflix'],
#  ['', 'B: The Beginning', '2018', '', 'netflix'],
#  ['', 'Baadshaho', '2017', '', 'netflix'],
#  ['', 'Baaghi', '2016', '', 'netflix'],
#  ['', 'Baahubali 2: The Conclusion (Hindi Version)', '2017', '', 'netflix'],
#  ['',
#   'Baahubali 2: The Conclusion (Malayalam Version)',
#   '2017',
#   '',
#   'netflix'],
#  ['', 'Baahubali 2: The Conclusion (Tamil Version)', '2017', '', 'netflix'],
#  ['', 'Baahubali: The Beginning (English Version)', '2015', '', 'netflix'],
#  ['', 'Baahubali: The Beginning (Hindi Version)', '2015', '', 'netflix'],
#  ['', 'Baahubali: The Beginning (Malayalam Version)', '2015', '', 'netflix'],
#  ['', 'Baahubali: The Beginning (Tamil Version)', '2015', '', 'netflix'],
#  ['', 'Baazaar', '2018', '', 'netflix'],
#  ['', 'Babam ve Oğlum (My Father and My Son)', '2005', '', 'netflix'],
#  ['', 'Babes in Toyland', '1986', '', 'netflix'],
#  ['', 'Babes in Toyland', '1997', '', 'netflix'],
#  ['', 'Babs', '2017', '', 'netflix'],
#  ['', 'Baby', '2018', '', 'netflix'],
#  ['', 'Baby Animals in the Wild', '2015', '', 'netflix'],
#  ['', 'Baby Ballroom', '2018', '', 'netflix'],
#  ['', 'Baby Boy', '2001', '', 'netflix'],
#  ['', 'Baby Driver', '2017', '', 'netflix'],
#  ['', 'Baby Mama', '2008', '', 'netflix'],
#  ['', 'Babylon', '2014', '', 'netflix'],
#  ['', 'The Babysitter', '2017', '', 'netflix'],
#  ['', 'Bachelor Girls', '2016', '', 'netflix'],
#  ['', 'Back and Forth', '2016', '', 'netflix'],
#  ['', 'Back Street Girls -GOKUDOLS-', '2018', '', 'netflix'],
#  ['', 'Back to 1989', '2016', '', 'netflix'],
#  ['', 'Back to the 90s', '2015', '', 'netflix'],
#  ['', 'Back to the Future', '1985', '', 'netflix'],
#  ['', 'Back to the Future Part II', '1989', '', 'netflix'],
#  ['', 'Back to the Future Part III', '1990', '', 'netflix'],
#  ['', 'Back with the Ex', '2018', '', 'netflix'],
#  ['', 'The Back-Up Plan', '2010', '', 'netflix'],
#  ['', 'Backfire', '2019', '', 'netflix'],
#  ['', 'Backstage', '2017', '', 'netflix'],
#  ['', 'The Bad Batch', '2016', '', 'netflix'],
#  ['', 'Bad Blood', '2019', '', 'netflix'],
#  ['', 'Bad Company', '1972', '', 'netflix'],
#  ['', 'Bad Day for the Cut', '2017', '', 'netflix'],
#  ['', 'Bad Education', '2014', '', 'netflix'],
#  ['', 'Bad Guys', '2014', '', 'netflix'],
#  ['', 'Bad Guys: Vile City', '2018', '', 'netflix'],
#  ['', 'The Bad Kids', '2016', '', 'netflix'],
#  ['', 'Bad Moms', '2016', '', 'netflix'],
#  ['', 'Bad Move', '2017', '', 'netflix'],
#  ['', 'Bad Rap', '2016', '', 'netflix'],
#  ['', 'Bad Santa 2', '2016', '', 'netflix'],
#  ['', 'Bad Seeds', '2018', '', 'netflix'],
#  ['', 'Bad Teacher', '2011', '', 'netflix'],
#  ['', 'Badalte Rishton Ki Dalstaan', '2013', '', 'netflix'],
#  ['', 'Badha', '2006', '', 'netflix'],
#  ['', 'Badla', '2019', '', 'netflix'],
#  ['', 'Bait', '2012', '', 'netflix'],
#  ['', 'BAKI', '2018', '', 'netflix'],
#  ['', 'Bald Mountain', '2013', '', 'netflix'],
#  ['', 'The Ballad of Buster Scruggs', '2018', '', 'netflix'],
#  ['', 'Ballerina (Leap!)', '2016', '', 'netflix'],
#  ['', 'Balu Mahi', '2017', '', 'netflix'],
#  ['', 'Bana Masal Anlatma', '2015', '', 'netflix'],
#  ['', 'Band of Robbers', '2015', '', 'netflix'],
#  ['', 'Bandie', '1978', '', 'netflix'],
#  ['', 'Bang Rajan 2', '2010', '', 'netflix'],
#  ['', 'Bangkok Bachelors', '2016', '', 'netflix'],
#  ['', 'Bangkok Hell (Nor Chor)', '2002', '', 'netflix'],
#  ['', 'Bangkok Love Stories: Hey You!', '2018', '', 'netflix'],
#  ['', 'Bangkok Love Stories: Innocence', '2018', '', 'netflix'],
#  ['', 'Bangkok Love Stories: Objects of Affection', '2019', '', 'netflix'],
#  ['', 'Bangkok Love Stories: Plead', '2019', '', 'netflix'],
#  ['', 'Bangkok Traffic (Love) Story', '2009', '', 'netflix'],
#  ['', 'Barça Dreams', '2015', '', 'netflix'],
#  ['', 'The Bar', '2017', '', 'netflix'],
#  ['', 'Barakah Meets Barakah', '2016', '', 'netflix'],
#  ['', 'Barbecue', '2017', '', 'netflix'],
#  ['', 'Barbie Dolphin Magic', '2017', '', 'netflix'],
#  ['', 'Barbie Dreamhouse Adventures', '2018', '', 'netflix'],
#  ['', 'Barbie Life in the Dreamhouse', '2012', '', 'netflix'],
#  ['', 'Barbie: Happy Birthday to You!', '2017', '', 'netflix'],
#  ['',
#   "Barbra: The Music ... The Mem'ries ... The Magic!",
#   '2017',
#   '',
#   'netflix'],
#  ['', 'Barcelona: A Love Untold', '2016', '', 'netflix'],
#  ['', 'Bare', '2015', '', 'netflix'],
#  ['', 'Bare Knuckle Fight Club', '2017', '', 'netflix'],
#  ['', 'The Bare-Footed Kid', '1993', '', 'netflix'],
#  ['', 'Bareilly Ki Barfi', '2017', '', 'netflix'],
#  ['', 'Barely Lethal', '2015', '', 'netflix'],
#  ['', 'Barfi!', '2012', '', 'netflix'],
#  ['',
#   'The Barkley Marathons: The Race That Eats Its Young',
#   '2014',
#   '',
#   'netflix'],
#  ['', 'Barry', '2016', '', 'netflix'],
#  ['', 'Barsaat', '1995', '', 'netflix'],
#  ['', 'The Basement', '2018', '', 'netflix'],
#  ['', 'Basketball or Nothing', '2019', '', 'netflix'],
#  ['', 'Bat Pat', '2016', '', 'netflix'],
#  ['', 'Bates Motel', '2017', '', 'netflix'],
#  ['', 'Bathinda Express', '2016', '', 'netflix'],
#  ['', 'Batman Ninja', '2018', '', 'netflix'],
#  ['', 'The Battered Bastards of Baseball', '2014', '', 'netflix'],
#  ['', 'Battle', '2018', '', 'netflix'],
#  ['', 'Battle Drone', '2018', '', 'netflix'],
#  ['', 'The Battle of Midway', '1942', '', 'netflix'],
#  ['', 'Battle: Los Angeles', '2011', '', 'netflix'],
#  ['', 'Battlefield Recovery', '2016', '', 'netflix'],
#  ['', 'Battlefish', '2018', '', 'netflix'],
#  ['', 'Battles - Kong: King of the Apes', '2016', '', 'netflix'],
#  ['', 'Bayonet (Bayoneta)', '2019', '', 'netflix'],
#  ['', 'Baywatch', '2017', '', 'netflix'],
#  ['', 'Bbuddah Hoga Terra Baap', '2011', '', 'netflix'],
#  ['', 'Be Here Now', '2015', '', 'netflix'],
#  ['', 'Be Somebody', '2016', '', 'netflix'],
#  ['', 'Be with Me', '2015', '', 'netflix'],
#  ['', 'Be with You', '2015', '', 'netflix'],
#  ['', 'Beach Rats', '2017', '', 'netflix'],
#  ['', 'Beak & Brain: Genius Birds From Down Under', '2013', '', 'netflix'],
#  ['', 'Bean: The Ultimate Disaster Movie', '1997', '', 'netflix'],
#  ['', 'Beary Tales', '2013', '', 'netflix'],
#  ['', 'The Beast Stalker (Ching yan)', '2008', '', 'netflix'],
#  ['', 'The Beast Within', '1982', '', 'netflix'],
#  ['', 'Beasts of No Nation', '2015', '', 'netflix'],
#  ['', 'Beat Bugs', '2018', '', 'netflix'],
#  ['', 'Beat Bugs: All Together Now', '2017', '', 'netflix'],
#  ['', 'Beat Bugs: Happy Birthday to You!', '2017', '', 'netflix'],
#  ['', 'The Beat', '2012', '', 'netflix'],
#  ['', 'Beating Again', '2015', '', 'netflix'],
#  ['', 'Beats', '2019', '', 'netflix'],
#  ['', 'Beauties of the Night', '2016', '', 'netflix'],
#  ['', 'Beautiful Gong Shim', '2016', '', 'netflix'],
#  ['', 'Beauty and the Beast', '2017', '', 'netflix'],
#  ['', 'Beauty and the Bestie', '2015', '', 'netflix'],
#  ['', 'Beauty and the Bitches', '2016', '', 'netflix'],
#  ['', 'Beauty Inside', '2018', '', 'netflix'],
#  ['', 'Because of Soccer (Gara-Gara Bola)', '2008', '', 'netflix'],
#  ['', "Because We're Heading Out (Ashan Kharjeen)", '2016', '', 'netflix'],
#  ['', 'Becoming Champions', '2018', '', 'netflix'],
#  ['', 'Bedeviled', '2016', '', 'netflix'],
#  ['', 'Bee Movie', '2007', '', 'netflix'],
#  ['', 'Been So Long', '2018', '', 'netflix'],
#  ['', 'Beethoven Virus', '2008', '', 'netflix'],
#  ['', 'Before I Fall', '2017', '', 'netflix'],
#  ['', 'Before I Wake', '2016', '', 'netflix'],
#  ['', 'Before the Flood', '2016', '', 'netflix'],
#  ['', 'The Beginning of Life: The Series', '2016', '', 'netflix'],
#  ['', 'The Beguiled', '2017', '', 'netflix'],
#  ['',
#   'Behind "The Cove": The Quiet Japanese Speak Out',
#   '2016',
#   '',
#   'netflix'],
#  ['', 'Behind Enemy Lines', '1997', '', 'netflix'],
#  ['', 'Behind the Curtain: Todrick Hall', '2017', '', 'netflix'],
#  ['', 'Behind the Curve', '2018', '', 'netflix'],
#  ['', 'Behind the Newsroom', '2015', '', 'netflix'],
#  ['', 'Behzat Ç', '2010', '', 'netflix'],
#  ['', 'Beiimaan Love', '2016', '', 'netflix'],
#  ['', "Being Elmo: A Puppeteer's Journey", '2011', '', 'netflix'],
#  ['', 'Being George Clooney', '2016', '', 'netflix'],
#  ['', 'Being Human (U.K.)', '2012', '', 'netflix'],
#  ['', 'Being Napoleon', '2018', '', 'netflix'],
#  ['', 'Belgica', '2016', '', 'netflix'],
#  ['', 'Belief: The Possession of Janet Moses', '2015', '', 'netflix'],
#  ['', 'Belle', '2013', '', 'netflix'],
#  ['', 'Below Her Mouth', '2016', '', 'netflix'],
#  ['', "Ben & Holly's Little Kingdom", '2009', '', 'netflix'],
#  ['', 'Benidorm', '2018', '', 'netflix'],
#  ['', 'Benji', '2018', '', 'netflix'],
#  ['', 'Berlin Calling', '2008', '', 'netflix'],
#  ['', 'Berlin Kaplani', '2012', '', 'netflix'],
#  ['', 'Bert Kreischer: Secret Time', '2018', '', 'netflix'],
#  ['', 'Bert Kreischer: The Machine', '2016', '', 'netflix'],
#  ['', 'Best Lover', '2016', '', 'netflix'],
#  ['', 'The Best Man Holiday', '2013', '', 'netflix'],
#  ['', "Best Neighbors (Giran el-Sa'd)", '2014', '', 'netflix'],
#  ['', 'The Best of Me', '2014', '', 'netflix'],
#  ['', 'The Best of Rafał Rutkowski, Olka Szczęśniak', '2016', '', 'netflix'],
#  ['', 'Best Worst Thing That Ever Could Have Happened', '2016', '', 'netflix'],
#  ['', 'Best.Worst.Weekend.Ever.', '2018', '', 'netflix'],
#  ['', 'The Betrayed', '2008', '', 'netflix'],
#  ['', 'Better Call Saul', '2018', '', 'netflix'],
#  ['', 'Better Than Us', '2019', '', 'netflix'],
#  ['', 'Betting on Zero', '2017', '', 'netflix'],
#  ['', 'Between', '2016', '', 'netflix'],
#  ['', 'Between Worlds', '2018', '', 'netflix'],
#  ['', 'Bewafaa', '2005', '', 'netflix'],
#  ['', 'Bewildered Bolbol (Bolbol Hayran)', '2010', '', 'netflix'],
#  ['', 'Beyblade Burst', '2016', '', 'netflix'],
#  ['', 'Beyond', '2018', '', 'netflix'],
#  ['', 'Beyond All Boundaries', '2013', '', 'netflix'],
#  ['', 'Beyond Bollywood', '2013', '', 'netflix'],
#  ['', 'Beyond Skyline', '2017', '', 'netflix'],
#  ['', 'Beyond Stranger Things', '2017', '', 'netflix'],
#  ['', 'Beyond the Clouds', '2017', '', 'netflix'],
#  ['', 'The Beyond', '2017', '', 'netflix'],
#  ['', 'Bh Se Bhade', '2013', '', 'netflix'],
#  ['', 'Bhaage Re Mann', '2015', '', 'netflix'],
#  ['', 'Bhabi Ji Ghar Par Hain', '2015', '', 'netflix'],
#  ['', 'Bharya Athra Pora', '2013', '', 'netflix'],
#  ['', 'Bhasmasur', '2017', '', 'netflix'],
#  ['', 'Bhavesh Joshi Superhero', '2018', '', 'netflix'],
#  ['', 'Bheemayan', '2018', '', 'netflix'],
#  ['', 'Bhool Bhulaiyaa', '2007', '', 'netflix'],
#  ['', 'Bhoopadathil Illatha Oridam', '2012', '', 'netflix'],
#  ['', 'Bhouri', '2017', '', 'netflix'],
#  ['',
#   'Bibi & Tina: Girls Versus Boys (Bibi & Tina: Mädchen gegen Jungs)',
#   '2016',
#   '',
#   'netflix'],
#  ['', 'Bibi & Tina: Tohuwabohu Total', '2017', '', 'netflix'],
#  ['', 'Bibi and Tina', '2014', '', 'netflix'],
#  ['', 'Bibi and Tina II', '2014', '', 'netflix'],
#  ['', 'Bibik-Bibikku', '2016', '', 'netflix'],
#  ['', 'Big', '2012', '', 'netflix'],
#  ['', 'Big Bad Beetleborgs', '1997', '', 'netflix'],
#  ['', 'The Big Bang Theory', '2018', '', 'netflix'],
#  ['', 'Big Bear', '2017', '', 'netflix'],
#  ['', 'Big Daddy', '1999', '', 'netflix'],
#  ['', 'Big Dreams, Small Spaces', '2017', '', 'netflix'],
#  ['', 'The Big Family Cooking Showdown', '2017', '', 'netflix'],
#  ['', 'Big Mouth', '2019', '', 'netflix'],
#  ['', 'Big School', '2014', '', 'netflix'],
#  ['', 'The Big Short', '2015', '', 'netflix'],
#  ['', 'Big Top Pee-wee', '1988', '', 'netflix'],
#  ['', 'Biggie & Tupac', '2002', '', 'netflix'],
#  ['', "Bill Burr: I'm Sorry You Feel That Way", '2014', '', 'netflix'],
#  ['', 'Bill Burr: Walk Your Way Out', '2017', '', 'netflix'],
#  ['', 'Bill Burr: You People Are All the Same', '2012', '', 'netflix'],
#  ['', 'Bill Hicks: One Night Stand', '1991', '', 'netflix'],
#  ['', 'Bill Hicks: Reflections', '2015', '', 'netflix'],
#  ['', 'Bill Hicks: Relentless', '1992', '', 'netflix'],
#  ['', 'Bill Hicks: Revelations', '1993', '', 'netflix'],
#  ['', 'Bill Hicks: Sane Man', '1989', '', 'netflix'],
#  ['', 'Bill Nye Saves the World', '2018', '', 'netflix'],
#  ['', 'Bill Nye: Science Guy', '2017', '', 'netflix'],
#  ['', 'Billa', '2007', '', 'netflix'],
#  ['', 'Billu', '2009', '', 'netflix'],
#  ['', 'Billy Graham: An Extraordinary Journey', '2018', '', 'netflix'],
#  ['', 'Bilu Rakkhosh (Bilu: A Demon Within)', '2017', '', 'netflix'],
#  ['', 'Bioscope', '2015', '', 'netflix'],
#  ['', 'Bir Baba Hindu', '2016', '', 'netflix'],
#  ['', 'Bird Box', '2018', '', 'netflix'],
#  ['',
#   'Birdman or (The Unexpected Virtue of Ignorance)',
#   '2014',
#   '',
#   'netflix'],
#  ['', 'Birdshot', '2016', '', 'netflix'],
#  ['', 'Birth of a Beauty', '2014', '', 'netflix'],
#  ['', 'The Birth Reborn 3 (O Renascimento do Parto 3)', '2013', '', 'netflix'],
#  ['', 'The Birth Reborn (O Renascimento do Parto)', '2013', '', 'netflix'],
#  ['', 'The Birth Reborn (O Renascimento do Parto 2)', '2018', '', 'netflix'],
#  ['', 'Birthmarked', '2018', '', 'netflix'],
#  ['', 'Bitten', '2016', '', 'netflix'],
#  ['', 'Bitter Daisies (O sabor das margaridas)', '2018', '', 'netflix'],
#  ['', 'The Bittersweet', '2017', '', 'netflix'],
#  ['', 'Bittoo Boss', '2012', '', 'netflix'],
#  ['', 'Black', '2017', '', 'netflix'],
#  ['', "Black '47", '2018', '', 'netflix'],
#  ['', "Black Adder's A Christmas Carol", '1988', '', 'netflix'],
#  ['', 'Black Butler', '2014', '', 'netflix'],
#  ['', 'Black Crows', '2017', '', 'netflix'],
#  ['', 'Black Earth Rising', '2018', '', 'netflix'],
#  ['', 'The Black Godfather', '2019', '', 'netflix'],
#  ['', 'Black Hawk Down', '2001', '', 'netflix'],
#  ['', 'Black Heart', '2014', '', 'netflix'],
#  ['', 'Black Knight: The Man Who Guards Me', '2018', '', 'netflix'],
#  ['', 'Black Lightning', '2018', '', 'netflix'],
#  ['', 'Black Man White Skin', '2015', '', 'netflix'],
#  ['', 'Black Mirror', '2019', '', 'netflix'],
#  ['', 'Black Mirror: Bandersnatch', '2018', '', 'netflix'],
#  ['', 'The Black Panthers: Vanguard of the Revolution', '2015', '', 'netflix'],
#  ['', 'The Black Prince', '2017', '', 'netflix'],
#  ['', 'The Black Room', '2016', '', 'netflix'],
#  ['', 'Black Site Delta', '2017', '', 'netflix'],
#  ['', 'Black Snow', '2017', '', 'netflix'],
#  ['', 'Black Spot', '2017', '', 'netflix'],
#  ['', 'Black Summer', '2019', '', 'netflix'],
#  ['', 'Black Water', '2018', '', 'netflix'],
#  ['', 'Blackadder (Black Adder, The Black Adder)', '1989', '', 'netflix'],
#  ['', 'Blackfish', '2013', '', 'netflix'],
#  ['', 'BLAME!', '2017', '', 'netflix'],
#  ['', 'Blaze and the Monster Machines', '2014', '', 'netflix'],
#  ['', 'Blazing Transfer Students', '2017', '', 'netflix'],
#  ['', 'Bleach', '2005', '', 'netflix'],
#  ['', 'Bleach', '2018', '', 'netflix'],
#  ['', 'The Bleeding Edge', '2018', '', 'netflix'],
#  ['', 'Bleeding Steel', '2017', '', 'netflix'],
#  ['', 'Blessed Benefit', '2016', '', 'netflix'],
#  ['', 'The Bletchley Circle', '2014', '', 'netflix'],
#  ['', 'Blind', '2016', '', 'netflix'],
#  ['', 'The Blind Christ', '2016', '', 'netflix'],
#  ['', 'Blind Date', '2015', '', 'netflix'],
#  ['', 'Blind Detective', '2013', '', 'netflix'],
#  ['', 'The Blind Side', '2009', '', 'netflix'],
#  ['', 'Blindspotting', '2018', '', 'netflix'],
#  ['', 'Blockbuster', '2017', '', 'netflix'],
#  ['', 'Blood', '2015', '', 'netflix'],
#  ['', 'Blood & Treasures (Pit Sawat)', '2016', '', 'netflix'],
#  ['', 'Blood Father', '2016', '', 'netflix'],
#  ['', 'Blood Money', '2012', '', 'netflix'],
#  ['', 'Bloodline', '2017', '', 'netflix'],
#  ['', 'Blow', '2001', '', 'netflix'],
#  ['', 'Blown Away', '2019', '', 'netflix'],
#  ['', 'Blue Exorcist', '2017', '', 'netflix'],
#  ['', 'Blue Exorcist: The Movie', '2012', '', 'netflix'],
#  ['', 'Blue Is the Warmest Color', '2013', '', 'netflix'],
#  ['', 'Blue Jay', '2016', '', 'netflix'],
#  ['', 'Blue Mountain State: The Rise of Thadland', '2016', '', 'netflix'],
#  ['', 'Blue Planet II', '2017', '', 'netflix'],
#  ['',
#   'The Blue Planet: A Natural History of the Oceans',
#   '2001',
#   '',
#   'netflix'],
#  ['', 'The Blue Umbrella', '2005', '', 'netflix'],
#  ['', 'Blue Velvet', '1986', '', 'netflix'],
#  ['', 'Blurred Lines: Inside the Art World', '2017', '', 'netflix'],
#  ['', "BNK48: Girls Don't Cry", '2018', '', 'netflix'],
#  ['', 'Bo Burnham: Make Happy', '2016', '', 'netflix'],
#  ['', 'Bo Burnham: what.', '2013', '', 'netflix'],
#  ['', 'Bob Lazar: Area 51 & Flying Saucers', '2018', '', 'netflix'],
#  ['', 'Bob Ross: Beauty Is Everywhere', '1991', '', 'netflix'],
#  ['', "Bob's Broken Sleigh", '2015', '', 'netflix'],
#  ['', 'Bobby Kennedy for President', '2018', '', 'netflix'],
#  ['', 'Bobby Robson: More Than a Manager', '2018', '', 'netflix'],
#  ['', 'Bobby Sands: 66 Days', '2016', '', 'netflix'],
#  ['', 'Boca Juniors Confidential', '2018', '', 'netflix'],
#  ['', 'Bodyguard', '2018', '', 'netflix'],
#  ['', 'The Bodyguard (My Beloved Bodyguard)', '2016', '', 'netflix'],
#  ['', 'Bogda', '2018', '', 'netflix'],
#  ['', 'Boi', '2018', '', 'netflix'],
#  ['', 'BoJack Horseman', '2018', '', 'netflix'],
#  ['',
#   "BoJack Horseman Christmas Special: Sabrina's Christmas Wish",
#   '2014',
#   '',
#   'netflix'],
#  ['', 'Bokeh', '2017', '', 'netflix'],
#  ['', 'Bolívar', '2019', '', 'netflix'],
#  ['', 'Bollywood Calling', '2001', '', 'netflix'],
#  ['', 'Bomb Scared (Fe de etarras)', '2017', '', 'netflix'],
#  ['', 'The Bomb', '2016', '', 'netflix'],
#  ['', 'Bombairiya', '2018', '', 'netflix'],
#  ['', 'Bombay Talkies', '2013', '', 'netflix'],
#  ['', 'The Bombing (Air Strike)', '2018', '', 'netflix'],
#  ['', 'Bombshell', '2016', '', 'netflix'],
#  ['', 'Bon Bini Holland', '2015', '', 'netflix'],
#  ['', 'Bon Cop Bad Cop 2', '2017', '', 'netflix'],
#  ['', 'Bon Cop, Bad Cop', '2006', '', 'netflix'],
#  ['', 'BONDING', '2019', '', 'netflix'],
#  ['', 'The Bone Collector', '1999', '', 'netflix'],
#  ['', 'Bonus Family (Bonusfamiljen)', '2018', '', 'netflix'],
#  ['', 'Booba', '2019', '', 'netflix'],
#  ['', 'The Book of Henry', '2017', '', 'netflix'],
#  ['', 'The Book of Life', '2014', '', 'netflix'],
#  ['', 'The Bookshop', '2017', '', 'netflix'],
#  ['', 'Boom', '2003', '', 'netflix'],
#  ['', 'Boonie Bears: Spring Into Action', '2014', '', 'netflix'],
#  ['', 'Boonie Bears: The Big Top Secret', '2016', '', 'netflix'],
#  ['', 'Borderline', '2017', '', 'netflix'],
#  ['', 'Borderliner (Grenseland)', '2017', '', 'netflix'],
#  ['', 'Bordertown', '2016', '', 'netflix'],
#  ['', 'Born in Gaza (Nacido en Gaza)', '2014', '', 'netflix'],
#  ['', 'Born in Syria (Nacido en Siria)', '2016', '', 'netflix'],
#  ['', 'Born Strong', '2017', '', 'netflix'],
#  ['', 'Born to Be Free', '2016', '', 'netflix'],
#  ['', 'Boss', '2013', '', 'netflix'],
#  ['', 'The Boss Baby: Back in Business', '2018', '', 'netflix'],
#  ['', "The Boss's Daughter", '2015', '', 'netflix'],
#  ['', 'Bottersnikes & Gumbles', '2017', '', 'netflix'],
#  ['', 'Bottom', '1995', '', 'netflix'],
#  ['', 'Bottom of the World', '2017', '', 'netflix'],
#  ['', 'Boulevard', '2014', '', 'netflix'],
#  ['', 'Bountiful Blessings', '2011', '', 'netflix'],
#  ['', 'The Bounty', '1984', '', 'netflix'],
#  ['', 'The Boxtrolls', '2014', '', 'netflix'],
#  ['', 'Boy Bye', '2016', '', 'netflix'],
#  ['', 'The Boy in the Striped Pyjamas', '2008', '', 'netflix'],
#  ['', 'The Boy Who Harnessed the Wind', '2019', '', 'netflix'],
#  ['', 'The Boy', '2016', '', 'netflix'],
#  ['', 'The Boyfriend School', '1990', '', 'netflix'],
#  ['', 'Boyhood', '2014', '', 'netflix'],
#  ['', 'Boyka: Undisputed', '2016', '', 'netflix'],
#  ['', 'Boys in the Trees', '2016', '', 'netflix'],
#  ['', 'Boys Over Flowers', '2009', '', 'netflix'],
#  ['', 'Boyz n the Hood', '1991', '', 'netflix'],
#  ['', "Brad Paisley's Comedy Rodeo", '2017', '', 'netflix'],
#  ['', "Brad's Status", '2017', '', 'netflix'],
#  ['', 'Brahman Naman', '2016', '', 'netflix'],
#  ['', 'Brain Games', '2016', '', 'netflix'],
#  ['', 'Brain on Fire', '2016', '', 'netflix'],
#  ['', 'Brainchild', '2018', '', 'netflix'],
#  ['', 'Brave Miss World', '2013', '', 'netflix'],
#  ['', 'Brawl in Cell Block 99', '2017', '', 'netflix'],
#  ['', 'Breach', '2007', '', 'netflix'],
#  ['', 'Break Up 100 (Fun sau 100 chi)', '2014', '', 'netflix'],
#  ['', 'The Break with Michelle Wolf', '2018', '', 'netflix'],
#  ['', 'The Break', '2016', '', 'netflix'],
#  ['', 'The Break-Up', '2006', '', 'netflix'],
#  ['', 'The Breaker Upperers', '2018', '', 'netflix'],
#  ['', 'Breaking Bad', '2013', '', 'netflix'],
#  ['', 'Breaking Free', '2015', '', 'netflix'],
#  ['', 'Breaking Habits', '2019', '', 'netflix'],
#  ['', 'Breaking the Cycle', '2017', '', 'netflix'],
#  ['',
#   "Breaking the Magician's Code: Magic's Biggest Secrets Finally Revealed",
#   '2009',
#   '',
#   'netflix'],
#  ['', 'Breakout', '2010', '', 'netflix'],
#  ['', 'Breakup Buddies (Xin hua lu fang)', '2014', '', 'netflix'],
#  ['', 'The Breakup Playlist', '2015', '', 'netflix'],
#  ['', 'Breathe', '2017', '', 'netflix'],
#  ['', 'Brené Brown: The Call to Courage', '2019', '', 'netflix'],
#  ['', 'Brian Regan: Nunchucks and Flamethrowers', '2017', '', 'netflix'],
#  ['', 'Bridal Mask', '2012', '', 'netflix'],
#  ['', 'Bride For Rent', '2014', '', 'netflix'],
#  ['', 'Bridesmaids', '2011', '', 'netflix'],
#  ['', 'Bridget Christie: Stand Up for Her', '2016', '', 'netflix'],
#  ['', "Bridget Jones's Diary", '2001', '', 'netflix'],
#  ['', 'Bridget Jones: The Edge of Reason', '2004', '', 'netflix'],
#  ['', 'Bright', '2017', '', 'netflix'],
#  ...]

# %%
streaming=pd.DataFrame(metaDataList, columns =['Link','Title','Year','Availability','Service']).dropna().astype({'Year': 'int64'})
streaming.sort_values('Year')
# Out:
#                                                    Link  ...  Service
# 75    https://player.bfi.org.uk/free/film/watch-no-m...  ...      bfi
# 105   https://player.bfi.org.uk/free/film/watch-the-...  ...      bfi
# 102   https://player.bfi.org.uk/free/film/watch-scre...  ...      bfi
# 86    https://player.bfi.org.uk/free/film/watch-wedd...  ...      bfi
# 52    https://player.bfi.org.uk/free/film/watch-colo...  ...      bfi
# 68    https://player.bfi.org.uk/free/film/watch-the-...  ...      bfi
# 87    https://player.bfi.org.uk/free/film/watch-mini...  ...      bfi
# 85    https://player.bfi.org.uk/free/film/watch-a-wo...  ...      bfi
# 53    https://player.bfi.org.uk/free/film/watch-prin...  ...      bfi
# 74    https://player.bfi.org.uk/free/film/watch-pano...  ...      bfi
# 55    https://player.bfi.org.uk/free/film/watch-sola...  ...      bfi
# 103   https://player.bfi.org.uk/free/film/watch-a-tr...  ...      bfi
# 73    https://player.bfi.org.uk/free/film/watch-hull...  ...      bfi
# 61    https://player.bfi.org.uk/free/film/watch-tram...  ...      bfi
# 82    https://player.bfi.org.uk/free/film/watch-the-...  ...      bfi
# 116   https://player.bfi.org.uk/free/film/watch-lond...  ...      bfi
# 66    https://player.bfi.org.uk/free/film/watch-miss...  ...      bfi
# 94    https://player.bfi.org.uk/free/film/watch-haml...  ...      bfi
# 78    https://player.bfi.org.uk/free/film/watch-lt-p...  ...      bfi
# 124   https://player.bfi.org.uk/free/film/watch-fune...  ...      bfi
# 77    https://player.bfi.org.uk/free/film/watch-patr...  ...      bfi
# 76    https://player.bfi.org.uk/free/film/watch-show...  ...      bfi
# 69    https://player.bfi.org.uk/free/film/watch-nels...  ...      bfi
# 4210                                                     ...  netflix
# 106   https://player.bfi.org.uk/free/film/watch-hint...  ...      bfi
# 114   https://player.bfi.org.uk/free/film/watch-the-...  ...      bfi
# 89    https://player.bfi.org.uk/free/film/watch-high...  ...      bfi
# 119   https://player.bfi.org.uk/free/film/watch-arou...  ...      bfi
# 99    https://player.bfi.org.uk/free/film/watch-caef...  ...      bfi
# 115   https://player.bfi.org.uk/free/film/watch-refu...  ...      bfi
# ...                                                 ...  ...      ...
# 4839                                                     ...  netflix
# 2138                                                     ...  netflix
# 2925                                                     ...  netflix
# 1582                                                     ...  netflix
# 462                                                      ...  netflix
# 4493                                                     ...  netflix
# 4494                                                     ...  netflix
# 4495                                                     ...  netflix
# 2920                                                     ...  netflix
# 4496                                                     ...  netflix
# 4497                                                     ...  netflix
# 5225                                                     ...  netflix
# 2911                                                     ...  netflix
# 487                                                      ...  netflix
# 5581                                                     ...  netflix
# 866                                                      ...  netflix
# 4013                                                     ...  netflix
# 3574                                                     ...  netflix
# 5576                                                     ...  netflix
# 2678                                                     ...  netflix
# 4847                                                     ...  netflix
# 2157                                                     ...  netflix
# 1235                                                     ...  netflix
# 4843                                                     ...  netflix
# 4840                                                     ...  netflix
# 858                                                      ...  netflix
# 1555                                                     ...  netflix
# 5564                                                     ...  netflix
# 5605                                                     ...  netflix
# 4548                                                     ...  netflix
#
# [5937 rows x 5 columns]

# %%
moviels= pd.merge(ml, streaming,  how='inner', on=['Title','Year'], )

# %%
#generate a nice markdown table that can be pasted into Reddit
print(tabulate(moviels.drop(['Metascore','Language','Country','IMDBRating', 'Plot','Awards','imdbID'],axis=1).sort_values('Title').sort_values('Service')
, tablefmt="pipe", headers="keys", showindex=False))
# Out:
# | Title                                             | Genre                                        | Director                                    |   Year |   Runtime | Link                                                                     | Availability                | Service   |
# |:--------------------------------------------------|:---------------------------------------------|:--------------------------------------------|-------:|----------:|:-------------------------------------------------------------------------|:----------------------------|:----------|
# | A Trip to the Moon                                | Short, Adventure, Fantasy, Sci-Fi            | Georges Méliès                              |   1902 |        13 | https://player.bfi.org.uk/free/film/watch-a-trip-to-the-moon-1902-online |                             | bfi       |
# | Night of the Living Dead                          | Horror                                       | George A. Romero                            |   1968 |        96 | https://www.bbc.co.uk/iplayer/episode/b0078pw1/night-of-the-living-dead  | Available for over a year   | iplayer   |
# | The Big Short                                     | Biography, Comedy, Drama, History            | Adam McKay                                  |   2015 |       130 | https://www.bbc.co.uk/iplayer/episode/b06vq3yn/the-big-short             | Available until Tue 12:55am | iplayer   |
# | Cat People                                        | Fantasy, Horror, Thriller                    | Jacques Tourneur                            |   1942 |        73 | https://www.bbc.co.uk/iplayer/episode/b0078ns6/cat-people                | Available for over a year   | iplayer   |
# | Spotlight                                         | Crime, Drama, History                        | Tom McCarthy                                |   2015 |       129 | https://www.bbc.co.uk/iplayer/episode/b06vt9qf/spotlight                 | Available until Wed 12:45am | iplayer   |
# | The Red Shoes                                     | Drama, Music, Romance                        | Michael Powell, Emeric Pressburger          |   1948 |       134 | https://www.bbc.co.uk/iplayer/episode/b0074t6v/the-red-shoes             | Available for 16 days       | iplayer   |
# | 13TH                                              | Documentary, Crime, History                  | Ava DuVernay                                |   2016 |       100 |                                                                          |                             | netflix   |
# | The Five Venoms                                   | Action                                       | Cheh Chang                                  |   1978 |        97 |                                                                          |                             | netflix   |
# | The Cabin in the Woods                            | Comedy, Horror                               | Drew Goddard                                |   2011 |        95 |                                                                          |                             | netflix   |
# | Spotlight                                         | Crime, Drama, History                        | Tom McCarthy                                |   2015 |       129 |                                                                          |                             | netflix   |
# | The Grand Budapest Hotel                          | Adventure, Comedy, Drama                     | Wes Anderson                                |   2014 |        99 |                                                                          |                             | netflix   |
# | Spartacus                                         | Adventure, Biography, Drama, History, War    | Stanley Kubrick                             |   1960 |       197 |                                                                          |                             | netflix   |
# | Some Like It Hot                                  | Comedy, Romance                              | Billy Wilder                                |   1959 |       121 |                                                                          |                             | netflix   |
# | She's Gotta Have It                               | Comedy, Romance                              | Spike Lee                                   |   1986 |        84 |                                                                          |                             | netflix   |
# | Schindler's List                                  | Biography, Drama, History                    | Steven Spielberg                            |   1993 |       195 |                                                                          |                             | netflix   |
# | The Big Short                                     | Biography, Comedy, Drama, History            | Adam McKay                                  |   2015 |       130 |                                                                          |                             | netflix   |
# | The Hangover                                      | Comedy                                       | Todd Phillips                               |   2009 |       100 |                                                                          |                             | netflix   |
# | The King's Speech                                 | Biography, Drama, History                    | Tom Hooper                                  |   2010 |       118 |                                                                          |                             | netflix   |
# | San Pietro                                        | Documentary, Short, War                      | John Huston                                 |   1945 |        32 |                                                                          |                             | netflix   |
# | The Lord of the Rings: The Fellowship of the Ring | Adventure, Drama, Fantasy                    | Peter Jackson                               |   2001 |       178 |                                                                          |                             | netflix   |
# | The Lord of the Rings: The Return of the King     | Action, Adventure, Drama, Fantasy            | Peter Jackson                               |   2003 |       201 |                                                                          |                             | netflix   |
# | The Lord of the Rings: The Two Towers             | Adventure, Drama, Fantasy                    | Peter Jackson                               |   2002 |       179 |                                                                          |                             | netflix   |
# | The Princess Bride                                | Adventure, Family, Fantasy, Romance          | Rob Reiner                                  |   1987 |        98 |                                                                          |                             | netflix   |
# | The Revenant                                      | Action, Adventure, Biography, Drama, Western | Alejandro G. Iñárritu                       |   2015 |       156 |                                                                          |                             | netflix   |
# | The Social Network                                | Biography, Drama                             | David Fincher                               |   2010 |       120 |                                                                          |                             | netflix   |
# | The Stranger                                      | Crime, Drama, Film-Noir, Mystery, Thriller   | Orson Welles                                |   1946 |        95 |                                                                          |                             | netflix   |
# | The Terminator                                    | Action, Sci-Fi                               | James Cameron                               |   1984 |       107 |                                                                          |                             | netflix   |
# | The Theory of Everything                          | Biography, Drama, Romance                    | James Marsh                                 |   2014 |       123 |                                                                          |                             | netflix   |
# | The Thing                                         | Horror, Mystery, Sci-Fi                      | John Carpenter                              |   1982 |       109 |                                                                          |                             | netflix   |
# | The Wolf of Wall Street                           | Biography, Comedy, Crime, Drama              | Martin Scorsese                             |   2013 |       180 |                                                                          |                             | netflix   |
# | Thelma & Louise                                   | Adventure, Crime, Drama                      | Ridley Scott                                |   1991 |       130 |                                                                          |                             | netflix   |
# | The Hurt Locker                                   | Drama, Thriller, War                         | Kathryn Bigelow                             |   2008 |       131 |                                                                          |                             | netflix   |
# | RoboCop                                           | Action, Crime, Sci-Fi, Thriller              | Paul Verhoeven                              |   1987 |       102 |                                                                          |                             | netflix   |
# | Psycho                                            | Horror, Mystery, Thriller                    | Alfred Hitchcock                            |   1960 |       109 |                                                                          |                             | netflix   |
# | Tinker Tailor Soldier Spy                         | Drama, Mystery, Thriller                     | Tomas Alfredson                             |   2011 |       122 |                                                                          |                             | netflix   |
# | A Fish Called Wanda                               | Comedy, Crime                                | Charles Crichton, John Cleese               |   1988 |       108 |                                                                          |                             | netflix   |
# | Back to the Future                                | Adventure, Comedy, Sci-Fi                    | Robert Zemeckis                             |   1985 |       116 |                                                                          |                             | netflix   |
# | Blue Is the Warmest Color                         | Drama, Romance                               | Abdellatif Kechiche                         |   2013 |       180 |                                                                          |                             | netflix   |
# | Blue Velvet                                       | Drama, Mystery, Thriller                     | David Lynch                                 |   1986 |       120 |                                                                          |                             | netflix   |
# | Boyhood                                           | Drama                                        | Richard Linklater                           |   2014 |       165 |                                                                          |                             | netflix   |
# | Boyz n the Hood                                   | Crime, Drama                                 | John Singleton                              |   1991 |       112 |                                                                          |                             | netflix   |
# | Bridesmaids                                       | Comedy, Romance                              | Paul Feig                                   |   2011 |       125 |                                                                          |                             | netflix   |
# | Bull Durham                                       | Comedy, Romance, Sport                       | Ron Shelton                                 |   1988 |       108 |                                                                          |                             | netflix   |
# | Carrie                                            | Horror                                       | Brian De Palma                              |   1976 |        98 |                                                                          |                             | netflix   |
# | City of God                                       | Crime, Drama                                 | Fernando Meirelles, Kátia Lund(co-director) |   2002 |       130 |                                                                          |                             | netflix   |
# | Days of Heaven                                    | Drama, Romance                               | Terrence Malick                             |   1978 |        94 |                                                                          |                             | netflix   |
# | District 9                                        | Action, Sci-Fi, Thriller                     | Neill Blomkamp                              |   2009 |       112 |                                                                          |                             | netflix   |
# | Four Weddings and a Funeral                       | Comedy, Drama, Romance                       | Mike Newell                                 |   1994 |       117 |                                                                          |                             | netflix   |
# | Reservoir Dogs                                    | Crime, Drama, Thriller                       | Quentin Tarantino                           |   1992 |        99 |                                                                          |                             | netflix   |
# | Full Metal Jacket                                 | Drama, War                                   | Stanley Kubrick                             |   1987 |       116 |                                                                          |                             | netflix   |
# | Get Out                                           | Horror, Mystery, Thriller                    | Jordan Peele                                |   2017 |       104 |                                                                          |                             | netflix   |
# | Gladiator                                         | Action, Adventure, Drama                     | Ridley Scott                                |   2000 |       155 |                                                                          |                             | netflix   |
# | GoodFellas                                        | Crime, Drama                                 | Martin Scorsese                             |   1990 |       146 |                                                                          |                             | netflix   |
# | Inception                                         | Action, Adventure, Sci-Fi, Thriller          | Christopher Nolan                           |   2010 |       148 |                                                                          |                             | netflix   |
# | Johnny Guitar                                     | Drama, Western                               | Nicholas Ray                                |   1954 |       110 |                                                                          |                             | netflix   |
# | Jurassic Park                                     | Adventure, Sci-Fi, Thriller                  | Steven Spielberg                            |   1993 |       127 |                                                                          |                             | netflix   |
# | Kill Bill: Vol. 1                                 | Action, Crime, Thriller                      | Quentin Tarantino                           |   2003 |       111 |                                                                          |                             | netflix   |
# | Mean Streets                                      | Crime, Drama, Thriller                       | Martin Scorsese                             |   1973 |       112 |                                                                          |                             | netflix   |
# | Midnight Cowboy                                   | Drama                                        | John Schlesinger                            |   1969 |       113 |                                                                          |                             | netflix   |
# | Million Dollar Baby                               | Drama, Sport                                 | Clint Eastwood                              |   2004 |       132 |                                                                          |                             | netflix   |
# | Monty Python and the Holy Grail                   | Adventure, Comedy, Fantasy                   | Terry Gilliam, Terry Jones                  |   1975 |        91 |                                                                          |                             | netflix   |
# | Moonstruck                                        | Comedy, Drama, Romance                       | Norman Jewison                              |   1987 |       102 |                                                                          |                             | netflix   |
# | Platoon                                           | Drama, War                                   | Oliver Stone                                |   1986 |       120 |                                                                          |                             | netflix   |
# | Gangs of New York                                 | Crime, Drama                                 | Martin Scorsese                             |   2002 |       167 |                                                                          |                             | netflix   |
# | Under the Shadow                                  | Drama, Horror, Thriller, War                 | Babak Anvari                                |   2016 |        84 |                                                                          |                             | netflix   |
